# %%
import pandas as pd
import numpy as np

# %%
users_df = pd.read_csv('data_warehouse/staging/users_staging.csv')
course_progress_df = pd.read_csv('data_warehouse/staging/course_progress_staging.csv')
module_progress_df = pd.read_csv('data_warehouse/staging/module_progress_staging.csv')
courses_df = pd.read_csv('data_warehouse/staging/courses_staging.csv')
course_modules_df = pd.read_csv('data_warehouse/staging/modules_staging.csv')
course_assignment_df = pd.read_csv('data_warehouse/staging/course_assignment_staging.csv')

# %%
display(users_df)
list(users_df.columns)
# Out:
#                                   user_id                name  \
# 0    f19bff61-81de-4e03-8147-008253a87032          Robin Cole
# 1    2f53cffa-1270-4f2e-9e01-726bc3bfed45    Walter Cervantes
# 2    1ce90841-2636-451c-bb17-b52b3e957885        James Thomas
# 3    2dd31992-9126-445e-ad42-779e8b16bb10     Heather Freeman
# 4    c6599665-e128-4aa2-8751-a6fabab8b7b4        Julie Gamble
# ..                                    ...                 ...
# 195  2849e69f-113a-4c72-82cf-40abf7a62d0b     Charles Coleman
# 196  46f28ff0-7200-4df9-8cc2-c19edbe346c3        Stacy Travis
# 197  200a2dbf-af46-4ab6-ac75-ac40470a3f4d           Todd Dunn
# 198  209d9804-e95e-44c2-bdf1-5ac81c0fc911  Christopher Martin
# 199  31d9429a-5936-4ff9-8553-ea9aaacdc1d6        Michael Ruiz
#
#                          email               designation           created_at
# 0      sandracombs@example.com             Data Engineer  2024-08-02 11:05:06
# 1    trujillolance@example.org            UI/UX Designer  2024-01-01 22:39:45
# 2        jonesgreg@example.net           DevOps Engineer  2024-08-28 05:27:15
# 3    henrykristine@example.com  Cybersecurity Specialist  2024-05-19 17:01:57
# 4        sotowanda@example.com             AI Specialist  2024-01-27 23:58:58
# ..                         ...                       ...                  ...
# 195    salasnicole@example.net           Software Tester  2024-05-30 19:42:06
# 196        stacy46@example.com           DevOps Engineer  2024-05-24 10:37:26
# 197      moyercody@example.com           Software Tester  2024-08-23 22:33:59
# 198     bakerjanet@example.net             Web Developer  2024-02-19 16:36:57
# 199         gdavis@example.net            Data Scientist  2024-03-04 22:59:07
#
# [200 rows x 5 columns]
# ['user_id', 'name', 'email', 'designation', 'created_at']

# %%
display(course_progress_df)
list(course_progress_df.columns)
# Out:
#                              progress_id  \
# 0   be0f309b-f42a-4771-91da-7cb49241f3b4
# 1   5825756d-f3db-450f-9071-9fdc0bb60ba2
# 2   f4afd986-5849-43cc-a761-30bced491592
# 3   109f7300-378c-490c-b200-fc2402ff3543
# 4   88dbd4fd-4de4-4adb-a2be-1cec18a68243
# ..                                   ...
# 95  7d5533ef-8038-4bff-81a4-99c0b8c21b12
# 96  8a30bfbe-5725-4b15-98f4-bbd37d8a2920
# 97  932069e5-0da0-4ad5-85ec-458ce586278e
# 98  66b1d3d4-55b4-4163-88b3-785f9128f623
# 99  0c20b67c-388c-456c-b732-4cd8132020e5
#
#                              employee_id  \
# 0   e40bba8c-ae9b-4034-8a3b-d51b66db29f0
# 1   cc3a213f-ba7e-4521-b84b-9239a8794f3e
# 2   769946e5-25bd-4af4-bc79-0fe0c030d392
# 3   2f141ed2-8e58-4b44-acf7-7dc8999deb6d
# 4   aa9a89b8-3bc9-4935-8e84-d592c8487ffb
# ..                                   ...
# 95  e4fbfc98-2080-45d0-9f13-40b81f4b47f2
# 96  aa9a89b8-3bc9-4935-8e84-d592c8487ffb
# 97  5ea948d4-bd49-40b3-a880-39bbf6f0212d
# 98  d887ae6f-308e-49c1-b0c4-ae84b1f8b1fe
# 99  848c1cfb-848b-4dcf-8a14-f9c5a04520e4
#
#                                course_id  completion_percentage  score  \
# 0   456db36d-de96-4dfa-865f-504165cce6c9                    100     59
# 1   3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c                     41     67
# 2   a7e95994-0a4e-45ca-b383-99d5be874b27                     94     62
# 3   3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c                     81     43
# 4   d2787a3d-045e-498a-b193-364413af2581                     23     92
# ..                                   ...                    ...    ...
# 95  da410d39-f651-4996-ae71-4941debedc84                    100     96
# 96  8df30faf-3eef-4751-8ae5-d1983625866a                     25     71
# 97  31762771-9880-49ad-95d7-6280e016c4c8                     59     39
# 98  a8faead4-39cd-4b23-88e8-26b235b2371b                     16     64
# 99  a78b1ec0-ce93-4128-868c-66f14f6c2956                      7     26
#
#            completed_at
# 0   2024-03-08 12:07:59
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 95  2024-01-19 10:20:32
# 96                  NaN
# 97                  NaN
# 98                  NaN
# 99                  NaN
#
# [100 rows x 6 columns]
# ['progress_id',
#  'employee_id',
#  'course_id',
#  'completion_percentage',
#  'score',
#  'completed_at']

# %%
display(module_progress_df)
list(module_progress_df.columns)
# Out:
#                          module_progress_id  \
# 0      f580ee3f-9b66-4db8-929b-6a59107d9d79
# 1      4f7738ea-c0ae-46b5-87eb-71fd891212f0
# 2      cfb0c36d-e334-477e-9b2e-ddf5de4469fa
# 3      6fb9530d-19f3-483e-9049-3c6788a122bc
# 4      35eda1aa-d8d6-49c1-b21d-ffbab33b4172
# ...                                     ...
# 39995  30939e9b-8859-4290-b9c7-4e9ccce29529
# 39996  f861b54f-95fc-417e-a703-01d238be1c45
# 39997  bee976f2-786f-4557-aeec-78bbb50cf2bd
# 39998  8b239481-88d3-4049-aa1b-2cab500212ed
# 39999  920ea47a-187e-4836-9296-ada776968884
#
#                                 employee_id  \
# 0      f19bff61-81de-4e03-8147-008253a87032
# 1      f19bff61-81de-4e03-8147-008253a87032
# 2      f19bff61-81de-4e03-8147-008253a87032
# 3      f19bff61-81de-4e03-8147-008253a87032
# 4      f19bff61-81de-4e03-8147-008253a87032
# ...                                     ...
# 39995  31d9429a-5936-4ff9-8553-ea9aaacdc1d6
# 39996  31d9429a-5936-4ff9-8553-ea9aaacdc1d6
# 39997  31d9429a-5936-4ff9-8553-ea9aaacdc1d6
# 39998  31d9429a-5936-4ff9-8553-ea9aaacdc1d6
# 39999  31d9429a-5936-4ff9-8553-ea9aaacdc1d6
#
#                                   course_id  \
# 0      d2787a3d-045e-498a-b193-364413af2581
# 1      3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c
# 2      caf6a647-1ecb-40f5-bf37-025d5a3dac92
# 3      ed992d96-0b1d-4e23-9cb3-c51add5de066
# 4      1d0a930c-f2ce-4c91-87c6-1f164d31b1e9
# ...                                     ...
# 39995  267c8078-a278-4f19-ad40-f54a37fcd937
# 39996  80c2970a-6fad-4013-a5b5-0c9995d5ce5d
# 39997  ed992d96-0b1d-4e23-9cb3-c51add5de066
# 39998  43302bbd-3e91-4ffa-a9cd-71e39e7aa3d5
# 39999  06d2a954-eaa4-46e8-b258-2e1c6e06430b
#
#                                   module_id  is_completed         completed_at
# 0      68945dcf-2130-4730-8522-bdb3584fff82             0                  NaN
# 1      cc7bea47-6f5f-4704-914a-8d8d40b5d887             0                  NaN
# 2      ccb6173b-839e-4988-95e6-b3a655eb8e84             1  2024-08-17 07:48:46
# 3      87108a4b-0865-4738-8032-cf47b4879af7             1  2024-09-17 04:16:39
# 4      42d9dc98-bcfa-452e-a219-5bc366b67952             0                  NaN
# ...                                     ...           ...                  ...
# 39995  a4df9d8d-779e-412f-ba42-6af25384786d             1  2024-08-11 00:49:42
# 39996  e8ee54f2-6883-4c55-b0a8-ebb17b89f541             0                  NaN
# 39997  a0180cd0-20b7-4e16-acef-4a6186bf4fdd             0                  NaN
# 39998  40d029b7-98e7-4493-b035-ea0a3e6442ff             0                  NaN
# 39999  049769c0-b108-4f7e-a564-104354fc25c4             1  2024-09-05 19:34:08
#
# [40000 rows x 6 columns]
# ['module_progress_id',
#  'employee_id',
#  'course_id',
#  'module_id',
#  'is_completed',
#  'completed_at']

# %%
display(courses_df)
list(courses_df.columns)
# Out:
#                                course_id  \
# 0   8c614264-41a5-448f-a207-c2a6bc6ed5df
# 1   77d80c8e-5e9f-47b4-a5be-ab09906bcc97
# 2   259bab35-6deb-4708-a897-8d93f65996fe
# 3   bf4ffeaa-9551-4964-a648-b08604df65f6
# 4   3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c
# 5   f58d5820-c86c-47ac-829b-96c2cac3f4cb
# 6   d42a0ca8-2308-4124-9397-81be2ba03c55
# 7   00ac38e0-4297-47bd-bfc4-11e55ea46076
# 8   456db36d-de96-4dfa-865f-504165cce6c9
# 9   ed992d96-0b1d-4e23-9cb3-c51add5de066
# 10  7aa5f280-dc8b-4b39-866d-ef0840fe520d
# 11  80c2970a-6fad-4013-a5b5-0c9995d5ce5d
# 12  a733831b-b87a-4023-a299-074b964f8268
# 13  bb668ac3-aab3-4156-9aec-2863d893474b
# 14  a7e95994-0a4e-45ca-b383-99d5be874b27
# 15  1d0a930c-f2ce-4c91-87c6-1f164d31b1e9
# 16  93ebcdd6-22e4-477b-ad13-ae5281161c58
# 17  8df30faf-3eef-4751-8ae5-d1983625866a
# 18  da410d39-f651-4996-ae71-4941debedc84
# 19  418ee30c-866c-40d1-bef2-32565d41a10e
# 20  a78b1ec0-ce93-4128-868c-66f14f6c2956
# 21  d2787a3d-045e-498a-b193-364413af2581
# 22  06d2a954-eaa4-46e8-b258-2e1c6e06430b
# 23  a8faead4-39cd-4b23-88e8-26b235b2371b
# 24  b526b725-9287-4b1d-aa4e-0def70f9dbcd
# 25  b4c47ef9-ab01-459e-8d3f-51b60dbea9ab
# 26  267c8078-a278-4f19-ad40-f54a37fcd937
# 27  31762771-9880-49ad-95d7-6280e016c4c8
# 28  caf6a647-1ecb-40f5-bf37-025d5a3dac92
# 29  43302bbd-3e91-4ffa-a9cd-71e39e7aa3d5
#
#                                            title  \
# 0                     Configurable didactic core
# 1                       Monitored local encoding
# 2      Re-contextualized demand-driven migration
# 3                 Managed homogeneous middleware
# 4                 Synergistic analyzing leverage
# 5          Proactive grid-enabled conglomeration
# 6             Right-sized user-facing capability
# 7            Profit-focused reciprocal interface
# 8                   Expanded full-range protocol
# 9      Cross-group fresh-thinking knowledge user
# 10                    Extended didactic approach
# 11                    Robust user-facing project
# 12        Decentralized maximized data-warehouse
# 13           Synergized 6thgeneration complexity
# 14    Vision-oriented regional Graphic Interface
# 15                Exclusive system-worthy portal
# 16      Compatible even-keeled Graphic Interface
# 17               Down-sized even-keeled attitude
# 18        Customer-focused zero-defect challenge
# 19                    Adaptive bifurcated matrix
# 20                 Optional content-based matrix
# 21  Switchable upward-trending Graphic Interface
# 22           Automated well-modulated moratorium
# 23                   Synergized coherent synergy
# 24                   Progressive executive array
# 25                  Reactive background matrices
# 26                 Profound cohesive focus group
# 27             Reactive real-time superstructure
# 28                Reactive transitional database
# 29          Managed 4thgeneration data-warehouse
#
#                                           description  duration  modules  \
# 0   Option grow and system work glass face. Sign c...       168       10
# 1   Power imagine recognize year. Reason water dat...        68        8
# 2   Property eye dinner just after. Top police mat...        87        9
# 3   Animal believe first charge character report. ...       108        4
# 4   City study kind experience. Same bill exist re...       118        6
# 5   Two save law control catch interest. South the...        65        9
# 6   Behind camera street most especially market ne...        87        1
# 7   Thus vote east specific next let kitchen actua...        80        6
# 8   Officer example cultural charge. Woman treat t...        57        2
# 9   Carry central fight strategy yeah future. Chur...       155        3
# 10  South better build quality. Response window fr...       135        3
# 11  Including suggest best say cell factor south. ...       102        9
# 12  Chance run cost very someone your. Animal bill...       127        6
# 13  Course science while bad model. Part responsib...       137       10
# 14  Become above speech indicate. Physical throw u...       175        1
# 15  Material student reveal talk recognize. Popula...       148        8
# 16  Song author both treatment director.\nTraditio...       108        9
# 17  Player loss minute safe coach. Door beautiful ...       133        7
# 18  Effect organization administration above evide...       140        9
# 19  Land new economy. Pull single number continue ...       104        7
# 20  Physical white way culture him born industry. ...       161       10
# 21  Usually class prepare general after. Might tru...       161        6
# 22  Agree big drug lawyer. Laugh so because eviden...        56        9
# 23  Image effort radio adult specific bad beautifu...       132        4
# 24  Collection into sing party state risk speak sm...       121        2
# 25  Director must doctor pay floor. Despite why ki...       103        1
# 26  Often both key realize. Surface perform style ...        76        5
# 27  Form show summer. Word set road down under rea...       119        7
# 28  Entire car beat. Finally off significant impor...       135        4
# 29  Next ever article friend. Bit fight benefit en...       140        6
#
#              created_at                 tag
# 0   2024-02-10 07:30:16        Data Science
# 1   2024-04-04 03:11:06    Data Engineering
# 2   2024-09-11 01:38:20              DevOps
# 3   2024-03-02 00:29:31        Data Science
# 4   2024-07-14 10:25:00       Cybersecurity
# 5   2024-03-08 00:38:49       Generative AI
# 6   2024-02-11 02:41:56  Mobile Development
# 7   2024-02-22 22:25:38     Web Development
# 8   2024-06-14 15:58:40     Web Development
# 9   2024-05-21 07:58:00  Mobile Development
# 10  2024-10-09 00:12:47    Software Testing
# 11  2024-09-28 18:48:31        UI/UX Design
# 12  2024-09-18 15:46:54  Mobile Development
# 13  2024-05-29 09:24:51        UI/UX Design
# 14  2024-09-01 22:45:12        UI/UX Design
# 15  2024-08-06 03:36:06              DevOps
# 16  2024-09-25 01:51:19       Cybersecurity
# 17  2024-08-20 06:30:10    Software Testing
# 18  2024-02-05 19:30:42       Generative AI
# 19  2024-02-17 08:26:59        UI/UX Design
# 20  2024-09-08 01:14:42  Mobile Development
# 21  2024-05-13 07:57:54    Software Testing
# 22  2024-10-07 05:30:23       Cybersecurity
# 23  2024-10-06 01:09:24    Data Engineering
# 24  2024-01-31 16:42:52        UI/UX Design
# 25  2024-07-20 07:06:31       Cybersecurity
# 26  2024-06-23 12:04:12    Software Testing
# 27  2024-08-23 19:27:01        Data Science
# 28  2024-01-14 17:06:04       Cybersecurity
# 29  2024-06-08 08:25:20        UI/UX Design
# ['course_id',
#  'title',
#  'description',
#  'duration',
#  'modules',
#  'created_at',
#  'tag']

# %%
display(course_modules_df)
list(course_modules_df.columns)
# Out:
#                                 module_id  \
# 0    68945dcf-2130-4730-8522-bdb3584fff82
# 1    cc7bea47-6f5f-4704-914a-8d8d40b5d887
# 2    ccb6173b-839e-4988-95e6-b3a655eb8e84
# 3    87108a4b-0865-4738-8032-cf47b4879af7
# 4    42d9dc98-bcfa-452e-a219-5bc366b67952
# ..                                    ...
# 195  a4df9d8d-779e-412f-ba42-6af25384786d
# 196  e8ee54f2-6883-4c55-b0a8-ebb17b89f541
# 197  a0180cd0-20b7-4e16-acef-4a6186bf4fdd
# 198  40d029b7-98e7-4493-b035-ea0a3e6442ff
# 199  049769c0-b108-4f7e-a564-104354fc25c4
#
#                                 course_id  \
# 0    f58d5820-c86c-47ac-829b-96c2cac3f4cb
# 1    418ee30c-866c-40d1-bef2-32565d41a10e
# 2    d42a0ca8-2308-4124-9397-81be2ba03c55
# 3    da410d39-f651-4996-ae71-4941debedc84
# 4    259bab35-6deb-4708-a897-8d93f65996fe
# ..                                    ...
# 195  f58d5820-c86c-47ac-829b-96c2cac3f4cb
# 196  00ac38e0-4297-47bd-bfc4-11e55ea46076
# 197  b4c47ef9-ab01-459e-8d3f-51b60dbea9ab
# 198  00ac38e0-4297-47bd-bfc4-11e55ea46076
# 199  06d2a954-eaa4-46e8-b258-2e1c6e06430b
#
#                                          module_title  \
# 0               Re-engineered didactic info-mediaries
# 1         Devolved contextually-based instruction set
# 2    Open-source eco-centric Graphical User Interface
# 3              Multi-layered 6thgeneration monitoring
# 4                    Realigned dedicated architecture
# ..                                                ...
# 195                   User-friendly asymmetric access
# 196                Fully-configurable exuding concept
# 197                        Profound exuding algorithm
# 198            Configurable web-enabled collaboration
# 199                   Digitized encompassing strategy
#
#                                         module_content  module_duration  \
# 0    Lose popular worry whose very grow low. Lay bu...               15
# 1    Image various take national. Positive generati...               13
# 2    Feeling fire alone. Use final customer machine...               17
# 3    That test region else. Toward until ago argue....               27
# 4    Dream detail walk seek. Compare whatever cold ...               30
# ..                                                 ...              ...
# 195  Wish perform model hotel stop. Single shake pl...               14
# 196  How three laugh require sense defense enjoy. F...               19
# 197  Where especially fill agree. Mouth work approa...               29
# 198  Although from director think east feeling. Mea...               27
# 199  Draw author result off thought rise traditiona...               20
#
#               created_at
# 0    2024-07-07 17:19:52
# 1    2024-10-14 08:14:48
# 2    2024-10-05 16:47:01
# 3    2024-01-01 01:40:34
# 4    2024-09-09 11:46:37
# ..                   ...
# 195  2024-08-19 11:34:59
# 196  2024-07-31 03:21:08
# 197  2024-05-22 08:08:42
# 198  2024-06-24 00:28:55
# 199  2024-03-08 18:18:46
#
# [200 rows x 6 columns]
# ['module_id',
#  'course_id',
#  'module_title',
#  'module_content',
#  'module_duration',
#  'created_at']

# %%
display(course_assignment_df)
course_assignment_df.columns
# Out:
#                            assignment_id  \
# 0   342c59b0-d3ef-4419-bf9d-75164c7d9901
# 1   865d37df-adad-4dc5-b9b0-a6c0398750b4
# 2   32a31de5-eb6c-46c2-88d7-8e68cd650fef
# 3   d80cc164-3889-4c2e-b52e-737292af0e18
# 4   3846c574-b70a-4460-83b9-1ff1509fe634
# ..                                   ...
# 95  9f33f1eb-5b7b-422e-b0f1-65f29a3e892a
# 96  791fe2a4-ee53-4fb1-b39e-ba8db1dab911
# 97  f737742d-5c2f-4224-97a5-c9078f5fa7f7
# 98  4012ac2c-7299-4421-93bf-80b3e3223b89
# 99  accd8929-3d23-442e-a303-f11d5cc623f0
#
#                              employee_id  \
# 0   e40bba8c-ae9b-4034-8a3b-d51b66db29f0
# 1   cc3a213f-ba7e-4521-b84b-9239a8794f3e
# 2   769946e5-25bd-4af4-bc79-0fe0c030d392
# 3   2f141ed2-8e58-4b44-acf7-7dc8999deb6d
# 4   aa9a89b8-3bc9-4935-8e84-d592c8487ffb
# ..                                   ...
# 95  e4fbfc98-2080-45d0-9f13-40b81f4b47f2
# 96  aa9a89b8-3bc9-4935-8e84-d592c8487ffb
# 97  5ea948d4-bd49-40b3-a880-39bbf6f0212d
# 98  d887ae6f-308e-49c1-b0c4-ae84b1f8b1fe
# 99  848c1cfb-848b-4dcf-8a14-f9c5a04520e4
#
#                                course_id          assigned_at
# 0   456db36d-de96-4dfa-865f-504165cce6c9  2024-07-08 13:46:03
# 1   3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c  2024-02-10 14:55:30
# 2   a7e95994-0a4e-45ca-b383-99d5be874b27  2024-08-09 12:17:29
# 3   3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c  2024-09-10 02:00:21
# 4   d2787a3d-045e-498a-b193-364413af2581  2024-05-05 03:45:07
# ..                                   ...                  ...
# 95  da410d39-f651-4996-ae71-4941debedc84  2024-07-12 10:35:32
# 96  8df30faf-3eef-4751-8ae5-d1983625866a  2024-06-15 12:25:39
# 97  31762771-9880-49ad-95d7-6280e016c4c8  2024-09-03 00:17:06
# 98  a8faead4-39cd-4b23-88e8-26b235b2371b  2024-02-24 08:32:07
# 99  a78b1ec0-ce93-4128-868c-66f14f6c2956  2024-01-18 08:06:03
#
# [100 rows x 4 columns]
# Index(['assignment_id', 'employee_id', 'course_id', 'assigned_at'], dtype='object')

# %% [markdown]
# Merge dataframes

# %%
# Step 1: Merge users_df with course_progress_df on employee_id
merged_df = pd.merge(users_df, course_progress_df, left_on='user_id', right_on='employee_id', how='left')

# Step 2: Merge merged_df with courses_df to include course details
merged_df = pd.merge(merged_df, courses_df, on='course_id', how='left')

# Step 3: Merge module_progress_df with course_modules_df to get module details for each course
module_df = pd.merge(module_progress_df, course_modules_df, on='module_id', how='left')

# Step 4: Merge the module_df with merged_df to incorporate module completion info
final_df = pd.merge(merged_df, module_df,left_on=['user_id', 'course_id'], right_on=['employee_id', 'course_id_x'], how='left')

# %%
final_df = final_df[[
    'user_id', 'name', 'email', 'designation',   # From users_df
    'course_id', 'title', 'tag', 'completion_percentage', 'duration', 'score', 'completed_at_x',  # From course_progress_df and courses_df
    'module_id', 'module_title', 'is_completed', 'module_duration', 'completed_at_y'  # From module_progress_df and course_modules_df
]]

# Rename columns for clarity
final_df.rename(columns={
    'completed_at_x': 'course_completed_at',
    'completed_at_y': 'module_completed_at',
    'title': 'course_title',
    'tag': 'course_tag',
    'score': 'course_score',
    'duration': 'course_duration',
}, inplace=True)

# %%
final_df.columns
# Out:
# Index(['user_id', 'name', 'email', 'designation', 'course_id', 'course_title',
#        'course_tag', 'completion_percentage', 'course_duration',
#        'course_score', 'course_completed_at', 'module_id', 'module_title',
#        'is_completed', 'module_duration', 'module_completed_at'],
#       dtype='object')

# %%
final_df
# final_df.to_csv('final_df1.csv',index=False)
# Out:
#                                   user_id              name  \
# 0    f19bff61-81de-4e03-8147-008253a87032        Robin Cole
# 1    2f53cffa-1270-4f2e-9e01-726bc3bfed45  Walter Cervantes
# 2    1ce90841-2636-451c-bb17-b52b3e957885      James Thomas
# 3    2dd31992-9126-445e-ad42-779e8b16bb10   Heather Freeman
# 4    2dd31992-9126-445e-ad42-779e8b16bb10   Heather Freeman
# ..                                    ...               ...
# 779  31d9429a-5936-4ff9-8553-ea9aaacdc1d6      Michael Ruiz
# 780  31d9429a-5936-4ff9-8553-ea9aaacdc1d6      Michael Ruiz
# 781  31d9429a-5936-4ff9-8553-ea9aaacdc1d6      Michael Ruiz
# 782  31d9429a-5936-4ff9-8553-ea9aaacdc1d6      Michael Ruiz
# 783  31d9429a-5936-4ff9-8553-ea9aaacdc1d6      Michael Ruiz
#
#                          email               designation  \
# 0      sandracombs@example.com             Data Engineer
# 1    trujillolance@example.org            UI/UX Designer
# 2        jonesgreg@example.net           DevOps Engineer
# 3    henrykristine@example.com  Cybersecurity Specialist
# 4    henrykristine@example.com  Cybersecurity Specialist
# ..                         ...                       ...
# 779         gdavis@example.net            Data Scientist
# 780         gdavis@example.net            Data Scientist
# 781         gdavis@example.net            Data Scientist
# 782         gdavis@example.net            Data Scientist
# 783         gdavis@example.net            Data Scientist
#
#                                 course_id  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3    259bab35-6deb-4708-a897-8d93f65996fe
# 4    259bab35-6deb-4708-a897-8d93f65996fe
# ..                                    ...
# 779  77d80c8e-5e9f-47b4-a5be-ab09906bcc97
# 780  77d80c8e-5e9f-47b4-a5be-ab09906bcc97
# 781  77d80c8e-5e9f-47b4-a5be-ab09906bcc97
# 782  77d80c8e-5e9f-47b4-a5be-ab09906bcc97
# 783  77d80c8e-5e9f-47b4-a5be-ab09906bcc97
#
#                                   course_title        course_tag  \
# 0                                          NaN               NaN
# 1                                          NaN               NaN
# 2                                          NaN               NaN
# 3    Re-contextualized demand-driven migration            DevOps
# 4    Re-contextualized demand-driven migration            DevOps
# ..                                         ...               ...
# 779                   Monitored local encoding  Data Engineering
# 780                   Monitored local encoding  Data Engineering
# 781                   Monitored local encoding  Data Engineering
# 782                   Monitored local encoding  Data Engineering
# 783                   Monitored local encoding  Data Engineering
#
#      completion_percentage  course_duration  course_score course_completed_at  \
# 0                      NaN              NaN           NaN                 NaN
# 1                      NaN              NaN           NaN                 NaN
# 2                      NaN              NaN           NaN                 NaN
# 3                     88.0             87.0          58.0                 NaN
# 4                     88.0             87.0          58.0                 NaN
# ..                     ...              ...           ...                 ...
# 779                    9.0             68.0          39.0                 NaN
# 780                    9.0             68.0          39.0                 NaN
# 781                    9.0             68.0          39.0                 NaN
# 782                    9.0             68.0          39.0                 NaN
# 783                    9.0             68.0          39.0                 NaN
#
#                                 module_id  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3    55286945-a633-46cc-8474-315cc4c622fc
# 4    a7bfd185-1f31-4af8-b393-ea1943a48b43
# ..                                    ...
# 779  f54e705d-cedf-44ef-8de4-341f06daca2b
# 780  92120703-7e86-4748-98e3-662ab3fb44c4
# 781  dd4fb17f-292b-46e5-89b6-7c8acf1996ff
# 782  709e233c-de67-4776-bedc-d8b1a01ee3dc
# 783  ffc136c8-083f-49f1-a346-11084ea392a4
#
#                                     module_title  is_completed  \
# 0                                            NaN           NaN
# 1                                            NaN           NaN
# 2                                            NaN           NaN
# 3            Profit-focused explicit parallelism           0.0
# 4           Exclusive object-oriented middleware           1.0
# ..                                           ...           ...
# 779                      Advanced radical matrix           0.0
# 780                 Multi-lateral heuristic core           1.0
# 781                       Digitized 24/7 concept           0.0
# 782                   Diverse high-level ability           0.0
# 783  Synchronized zero administration complexity           0.0
#
#      module_duration  module_completed_at
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3               26.0                  NaN
# 4               21.0  2024-06-27 17:53:51
# ..               ...                  ...
# 779             30.0                  NaN
# 780             12.0  2024-02-14 11:15:26
# 781             22.0                  NaN
# 782             15.0                  NaN
# 783             15.0                  NaN
#
# [784 rows x 16 columns]

# %% [markdown]
# Employee Course KPI: This captures each employee’s course progress (average completion percentage and performance score). This will be useful for understanding how far employees have progressed in their courses and how they’re performing.

# %%
# Group by user and course to calculate total modules and completed modules per course
module_kpi = final_df.groupby(['user_id', 'course_id']).agg(
    total_modules=('module_id', 'count'),        # Total number of modules for the course
    modules_completed=('is_completed', 'sum')   # Number of completed modules (is_completed is 1 for completed)
).reset_index()

module_kpi.columns

display(module_kpi)
# Out:
#                                  user_id  \
# 0   02313e16-1e66-4e40-80c1-de80087e186f
# 1   0e102525-4073-488a-904e-c5f00a709555
# 2   10411182-6a30-41fb-b24c-1242a632057e
# 3   16eda4ba-42cd-4b9f-9db9-3a0e0285cab5
# 4   17c2a5fb-7682-45e3-9bd0-2ddc6431ef00
# ..                                   ...
# 95  f5818c93-e8ca-4df9-a16f-08d1024d9111
# 96  f5818c93-e8ca-4df9-a16f-08d1024d9111
# 97  f7ba1d77-7fa7-41c7-9915-bbdc1a0f0f89
# 98  f7ba1d77-7fa7-41c7-9915-bbdc1a0f0f89
# 99  f7ba1d77-7fa7-41c7-9915-bbdc1a0f0f89
#
#                                course_id  total_modules  modules_completed
# 0   93ebcdd6-22e4-477b-ad13-ae5281161c58              0                0.0
# 1   a7e95994-0a4e-45ca-b383-99d5be874b27              9                4.0
# 2   a8faead4-39cd-4b23-88e8-26b235b2371b              6                5.0
# 3   8c614264-41a5-448f-a207-c2a6bc6ed5df              6                3.0
# 4   31762771-9880-49ad-95d7-6280e016c4c8              8                6.0
# ..                                   ...            ...                ...
# 95  a8faead4-39cd-4b23-88e8-26b235b2371b              9                2.0
# 96  b526b725-9287-4b1d-aa4e-0def70f9dbcd              3                1.0
# 97  00ac38e0-4297-47bd-bfc4-11e55ea46076             12                5.0
# 98  267c8078-a278-4f19-ad40-f54a37fcd937              5                3.0
# 99  b4c47ef9-ab01-459e-8d3f-51b60dbea9ab              3                1.0
#
# [100 rows x 4 columns]

# %%
# Merge the module_kpi with the final_df to incorporate total and completed modules
final_df = pd.merge(final_df, module_kpi, on=['user_id', 'course_id'], how='left')

display(final_df.columns)
# Out:
# Index(['user_id', 'name', 'email', 'designation', 'course_id', 'course_title',
#        'course_tag', 'completion_percentage', 'course_duration',
#        'course_score', 'course_completed_at', 'module_id', 'module_title',
#        'is_completed', 'module_duration', 'module_completed_at',
#        'total_modules', 'modules_completed'],
#       dtype='object')

# %%
# Calculate completed percentage for the modules
final_df['completion_percentage'] = (final_df['modules_completed'] / final_df['total_modules']) * 100

# %%
# Employee KPI: Each employee's course progress with total modules, completed modules, and module completion percentage
employee_course_kpi = final_df.groupby(['user_id', 'name', 'designation', 'course_id', 'course_title', 'course_tag']).agg(
    total_modules=('total_modules', 'first'),
    modules_completed=('modules_completed', 'first'),
    completion_percentage=('completion_percentage', 'first'),
    course_score=('course_score', 'first')
).reset_index()

# %%
def calculate_performance_score(progress_df):
    # Group by employee and calculate total score and total max score
    performance_summary = progress_df.groupby('user_id').agg(
        total_score=('course_score', 'sum'),  # Sum of course scores
        total_max_score=('course_score', lambda x: len(x) * 100),  # Assuming max score for each course is 100
        completed_courses=('completion_percentage', lambda x: (x == 100).sum())  # Count of fully completed courses
    ).reset_index()

    # Calculate performance score as a percentage
    performance_summary['performance_score'] = (performance_summary['total_score'] / performance_summary['total_max_score']) * 100
    return performance_summary

# %%
# Update performance score for each employee
performance_summary = calculate_performance_score(final_df)

# %%
final_df = pd.merge(final_df, performance_summary[['user_id', 'performance_score']], on='user_id', how='left')

# %%
final_df.to_csv('data_warehouse/report/final_df.csv', index=False)

# %%
final_df.columns
# Out:
# Index(['user_id', 'name', 'email', 'designation', 'course_id', 'course_title',
#        'course_tag', 'completion_percentage', 'course_duration',
#        'course_score', 'course_completed_at', 'module_id', 'module_title',
#        'is_completed', 'module_duration', 'module_completed_at',
#        'total_modules', 'modules_completed', 'performance_score'],
#       dtype='object')

# %%
filtered_df = final_df[[
    'user_id', 'name', 'designation', 'course_id', 'course_title', 'course_tag',
    'course_duration','modules_completed', 'total_modules', 'completion_percentage', 'course_score', 'performance_score'
]]

# %%
employee_performance_kpi = filtered_df.groupby([
    'user_id', 'name', 'designation', 'course_id', 'course_title', 'course_tag', 
    'course_duration','modules_completed', 'total_modules', 'completion_percentage', 'course_score', 'performance_score'
]).first().reset_index()

display(employee_performance_kpi)
# Out:
#                                  user_id            name      designation  \
# 0   0e102525-4073-488a-904e-c5f00a709555      Terry Pena  Software Tester
# 1   10411182-6a30-41fb-b24c-1242a632057e      Erik Owens   Data Scientist
# 2   16eda4ba-42cd-4b9f-9db9-3a0e0285cab5   Amanda Hayden   Data Scientist
# 3   17c2a5fb-7682-45e3-9bd0-2ddc6431ef00    Carol Howard   Data Scientist
# 4   1c4b38aa-0361-49eb-a5bd-372a50bc990e  James Matthews    AI Specialist
# ..                                   ...             ...              ...
# 94  f5818c93-e8ca-4df9-a16f-08d1024d9111    Kevin Dudley   UI/UX Designer
# 95  f5818c93-e8ca-4df9-a16f-08d1024d9111    Kevin Dudley   UI/UX Designer
# 96  f7ba1d77-7fa7-41c7-9915-bbdc1a0f0f89    Billy Prince   UI/UX Designer
# 97  f7ba1d77-7fa7-41c7-9915-bbdc1a0f0f89    Billy Prince   UI/UX Designer
# 98  f7ba1d77-7fa7-41c7-9915-bbdc1a0f0f89    Billy Prince   UI/UX Designer
#
#                                course_id  \
# 0   a7e95994-0a4e-45ca-b383-99d5be874b27
# 1   a8faead4-39cd-4b23-88e8-26b235b2371b
# 2   8c614264-41a5-448f-a207-c2a6bc6ed5df
# 3   31762771-9880-49ad-95d7-6280e016c4c8
# 4   8c614264-41a5-448f-a207-c2a6bc6ed5df
# ..                                   ...
# 94  a8faead4-39cd-4b23-88e8-26b235b2371b
# 95  b526b725-9287-4b1d-aa4e-0def70f9dbcd
# 96  00ac38e0-4297-47bd-bfc4-11e55ea46076
# 97  267c8078-a278-4f19-ad40-f54a37fcd937
# 98  b4c47ef9-ab01-459e-8d3f-51b60dbea9ab
#
#                                   course_title        course_tag  \
# 0   Vision-oriented regional Graphic Interface      UI/UX Design
# 1                  Synergized coherent synergy  Data Engineering
# 2                   Configurable didactic core      Data Science
# 3            Reactive real-time superstructure      Data Science
# 4                   Configurable didactic core      Data Science
# ..                                         ...               ...
# 94                 Synergized coherent synergy  Data Engineering
# 95                 Progressive executive array      UI/UX Design
# 96         Profit-focused reciprocal interface   Web Development
# 97               Profound cohesive focus group  Software Testing
# 98                Reactive background matrices     Cybersecurity
#
#     course_duration  modules_completed  total_modules  completion_percentage  \
# 0             175.0                4.0            9.0              44.444444
# 1             132.0                5.0            6.0              83.333333
# 2             168.0                3.0            6.0              50.000000
# 3             119.0                6.0            8.0              75.000000
# 4             168.0                2.0            5.0              40.000000
# ..              ...                ...            ...                    ...
# 94            132.0                2.0            9.0              22.222222
# 95            121.0                1.0            3.0              33.333333
# 96             80.0                5.0           12.0              41.666667
# 97             76.0                3.0            5.0              60.000000
# 98            103.0                1.0            3.0              33.333333
#
#     course_score  performance_score
# 0           45.0              45.00
# 1           74.0              74.00
# 2           89.0              89.00
# 3           92.0              92.00
# 4           56.0              56.00
# ..           ...                ...
# 94          96.0              94.75
# 95          91.0              94.75
# 96          46.0              59.55
# 97          84.0              59.55
# 98          73.0              59.55
#
# [99 rows x 12 columns]

# %% [markdown]
# TOP 5 EMPLOYEES WITH HIGHEST PERFORMANCE SCORE

# %%
top_5_employees = employee_performance_kpi.nlargest(5, 'performance_score')

top_5_employees.head()
# Out:
#                                  user_id            name      designation  \
# 22  5ddf51cd-9bde-4afe-9961-8ad455b80030  Michael Travis  Software Tester
# 46  96d79700-8fa5-4092-a3cc-cbf34f530452      Kirk Payne    Data Engineer
# 10  2c7fc651-e5b7-4a60-ac2e-d510734efef1     Riley Blake   Data Scientist
# 94  f5818c93-e8ca-4df9-a16f-08d1024d9111    Kevin Dudley   UI/UX Designer
# 95  f5818c93-e8ca-4df9-a16f-08d1024d9111    Kevin Dudley   UI/UX Designer
#
#                                course_id                         course_title  \
# 22  77d80c8e-5e9f-47b4-a5be-ab09906bcc97             Monitored local encoding
# 46  06d2a954-eaa4-46e8-b258-2e1c6e06430b  Automated well-modulated moratorium
# 10  3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c       Synergistic analyzing leverage
# 94  a8faead4-39cd-4b23-88e8-26b235b2371b          Synergized coherent synergy
# 95  b526b725-9287-4b1d-aa4e-0def70f9dbcd          Progressive executive array
#
#           course_tag  course_duration  modules_completed  total_modules  \
# 22  Data Engineering             68.0                7.0            9.0
# 46     Cybersecurity             56.0                7.0           13.0
# 10     Cybersecurity            118.0                6.0            9.0
# 94  Data Engineering            132.0                2.0            9.0
# 95      UI/UX Design            121.0                1.0            3.0
#
#     completion_percentage  course_score  performance_score
# 22              77.777778          98.0              98.00
# 46              53.846154          98.0              98.00
# 10              66.666667          97.0              97.00
# 94              22.222222          96.0              94.75
# 95              33.333333          91.0              94.75

# %%
employee_performance_kpi.columns
# Out:
# Index(['user_id', 'name', 'designation', 'course_id', 'course_title',
#        'course_tag', 'course_duration', 'modules_completed', 'total_modules',
#        'completion_percentage', 'course_score', 'performance_score'],
#       dtype='object')

# %%
employee_performance_kpi.to_csv('data_warehouse/report/employee_performance_kpi.csv', index=False)

# %% [markdown]
# Course Completion by Tag

# %%
course_completion_by_tag = final_df.groupby(['course_tag']).agg(
    total_courses=('course_id', 'nunique'),
    total_completed_courses=('completion_percentage', lambda x: (x >= 100).sum()),
    average_completion_percentage=('completion_percentage', 'mean')
).reset_index()

display(course_completion_by_tag)
# Out:
#            course_tag  total_courses  total_completed_courses  \
# 0       Cybersecurity              5                        0
# 1    Data Engineering              2                        5
# 2        Data Science              3                        0
# 3              DevOps              2                        0
# 4       Generative AI              2                        0
# 5  Mobile Development              4                        0
# 6    Software Testing              4                        0
# 7        UI/UX Design              5                        3
# 8     Web Development              2                        5
#
#    average_completion_percentage
# 0                      47.244094
# 1                      53.333333
# 2                      47.435897
# 3                      56.250000
# 4                      57.142857
# 5                      57.798165
# 6                      40.476190
# 7                      51.376147
# 8                      47.222222

# %%
top_5_courses = final_df.nlargest(10, 'completion_percentage')


top_5_courses[['course_id', 'course_title', 'completion_percentage']].head()
# Out:
#                                 course_id                 course_title  \
# 419  a8faead4-39cd-4b23-88e8-26b235b2371b  Synergized coherent synergy
# 420  a8faead4-39cd-4b23-88e8-26b235b2371b  Synergized coherent synergy
# 421  a8faead4-39cd-4b23-88e8-26b235b2371b  Synergized coherent synergy
# 422  a8faead4-39cd-4b23-88e8-26b235b2371b  Synergized coherent synergy
# 423  a8faead4-39cd-4b23-88e8-26b235b2371b  Synergized coherent synergy
#
#      completion_percentage
# 419                  100.0
# 420                  100.0
# 421                  100.0
# 422                  100.0
# 423                  100.0

# %% [markdown]
# Course Enrollment KPI

# %%
course_enrollment_kpi = final_df.groupby(['course_id', 'course_title']).agg(
    enrolled_employees=('user_id', 'nunique')
).reset_index()

display(course_enrollment_kpi)
# Out:
#                                course_id  \
# 0   00ac38e0-4297-47bd-bfc4-11e55ea46076
# 1   06d2a954-eaa4-46e8-b258-2e1c6e06430b
# 2   1d0a930c-f2ce-4c91-87c6-1f164d31b1e9
# 3   259bab35-6deb-4708-a897-8d93f65996fe
# 4   267c8078-a278-4f19-ad40-f54a37fcd937
# 5   31762771-9880-49ad-95d7-6280e016c4c8
# 6   3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c
# 7   418ee30c-866c-40d1-bef2-32565d41a10e
# 8   456db36d-de96-4dfa-865f-504165cce6c9
# 9   77d80c8e-5e9f-47b4-a5be-ab09906bcc97
# 10  7aa5f280-dc8b-4b39-866d-ef0840fe520d
# 11  80c2970a-6fad-4013-a5b5-0c9995d5ce5d
# 12  8c614264-41a5-448f-a207-c2a6bc6ed5df
# 13  8df30faf-3eef-4751-8ae5-d1983625866a
# 14  93ebcdd6-22e4-477b-ad13-ae5281161c58
# 15  a733831b-b87a-4023-a299-074b964f8268
# 16  a78b1ec0-ce93-4128-868c-66f14f6c2956
# 17  a7e95994-0a4e-45ca-b383-99d5be874b27
# 18  a8faead4-39cd-4b23-88e8-26b235b2371b
# 19  b4c47ef9-ab01-459e-8d3f-51b60dbea9ab
# 20  b526b725-9287-4b1d-aa4e-0def70f9dbcd
# 21  bb668ac3-aab3-4156-9aec-2863d893474b
# 22  bf4ffeaa-9551-4964-a648-b08604df65f6
# 23  caf6a647-1ecb-40f5-bf37-025d5a3dac92
# 24  d2787a3d-045e-498a-b193-364413af2581
# 25  d42a0ca8-2308-4124-9397-81be2ba03c55
# 26  da410d39-f651-4996-ae71-4941debedc84
# 27  ed992d96-0b1d-4e23-9cb3-c51add5de066
# 28  f58d5820-c86c-47ac-829b-96c2cac3f4cb
#
#                                     course_title  enrolled_employees
# 0            Profit-focused reciprocal interface                   4
# 1            Automated well-modulated moratorium                   6
# 2                 Exclusive system-worthy portal                   1
# 3      Re-contextualized demand-driven migration                   2
# 4                  Profound cohesive focus group                   1
# 5              Reactive real-time superstructure                   4
# 6                 Synergistic analyzing leverage                   4
# 7                     Adaptive bifurcated matrix                   4
# 8                   Expanded full-range protocol                   6
# 9                       Monitored local encoding                   2
# 10                    Extended didactic approach                   1
# 11                    Robust user-facing project                   1
# 12                    Configurable didactic core                   7
# 13               Down-sized even-keeled attitude                   3
# 14      Compatible even-keeled Graphic Interface                   4
# 15        Decentralized maximized data-warehouse                   6
# 16                 Optional content-based matrix                   3
# 17    Vision-oriented regional Graphic Interface                   7
# 18                   Synergized coherent synergy                   8
# 19                  Reactive background matrices                   3
# 20                   Progressive executive array                   3
# 21           Synergized 6thgeneration complexity                   2
# 22                Managed homogeneous middleware                   1
# 23                Reactive transitional database                   3
# 24  Switchable upward-trending Graphic Interface                   2
# 25            Right-sized user-facing capability                   2
# 26        Customer-focused zero-defect challenge                   2
# 27     Cross-group fresh-thinking knowledge user                   4
# 28         Proactive grid-enabled conglomeration                   4

# %%
top_5_courses = course_enrollment_kpi.nlargest(5, 'enrolled_employees')


top_5_courses.head()
# Out:
#                                course_id  \
# 18  a8faead4-39cd-4b23-88e8-26b235b2371b
# 12  8c614264-41a5-448f-a207-c2a6bc6ed5df
# 17  a7e95994-0a4e-45ca-b383-99d5be874b27
# 1   06d2a954-eaa4-46e8-b258-2e1c6e06430b
# 8   456db36d-de96-4dfa-865f-504165cce6c9
#
#                                   course_title  enrolled_employees
# 18                 Synergized coherent synergy                   8
# 12                  Configurable didactic core                   7
# 17  Vision-oriented regional Graphic Interface                   7
# 1          Automated well-modulated moratorium                   6
# 8                 Expanded full-range protocol                   6

# %% [markdown]
# Course Completion KPI

# %%
course_completion_kpi = final_df.groupby(['course_id', 'course_title']).agg(
    total_enrolled=('user_id', 'count'),
    total_completed=('completion_percentage', lambda x: (x >= 100).sum()),
    completion_rate=('completion_percentage', 'mean')
).reset_index()

course_completion_kpi['completion_rate'] = (course_completion_kpi['total_completed'] / course_completion_kpi['total_enrolled']) * 100

display(course_completion_kpi)
# Out:
#                                course_id  \
# 0   00ac38e0-4297-47bd-bfc4-11e55ea46076
# 1   06d2a954-eaa4-46e8-b258-2e1c6e06430b
# 2   1d0a930c-f2ce-4c91-87c6-1f164d31b1e9
# 3   259bab35-6deb-4708-a897-8d93f65996fe
# 4   267c8078-a278-4f19-ad40-f54a37fcd937
# 5   31762771-9880-49ad-95d7-6280e016c4c8
# 6   3d8c4804-b06c-4ecf-a3f4-b6d8d9e1aa4c
# 7   418ee30c-866c-40d1-bef2-32565d41a10e
# 8   456db36d-de96-4dfa-865f-504165cce6c9
# 9   77d80c8e-5e9f-47b4-a5be-ab09906bcc97
# 10  7aa5f280-dc8b-4b39-866d-ef0840fe520d
# 11  80c2970a-6fad-4013-a5b5-0c9995d5ce5d
# 12  8c614264-41a5-448f-a207-c2a6bc6ed5df
# 13  8df30faf-3eef-4751-8ae5-d1983625866a
# 14  93ebcdd6-22e4-477b-ad13-ae5281161c58
# 15  a733831b-b87a-4023-a299-074b964f8268
# 16  a78b1ec0-ce93-4128-868c-66f14f6c2956
# 17  a7e95994-0a4e-45ca-b383-99d5be874b27
# 18  a8faead4-39cd-4b23-88e8-26b235b2371b
# 19  b4c47ef9-ab01-459e-8d3f-51b60dbea9ab
# 20  b526b725-9287-4b1d-aa4e-0def70f9dbcd
# 21  bb668ac3-aab3-4156-9aec-2863d893474b
# 22  bf4ffeaa-9551-4964-a648-b08604df65f6
# 23  caf6a647-1ecb-40f5-bf37-025d5a3dac92
# 24  d2787a3d-045e-498a-b193-364413af2581
# 25  d42a0ca8-2308-4124-9397-81be2ba03c55
# 26  da410d39-f651-4996-ae71-4941debedc84
# 27  ed992d96-0b1d-4e23-9cb3-c51add5de066
# 28  f58d5820-c86c-47ac-829b-96c2cac3f4cb
#
#                                     course_title  total_enrolled  \
# 0            Profit-focused reciprocal interface              32
# 1            Automated well-modulated moratorium              46
# 2                 Exclusive system-worthy portal               3
# 3      Re-contextualized demand-driven migration              13
# 4                  Profound cohesive focus group               5
# 5              Reactive real-time superstructure              31
# 6                 Synergistic analyzing leverage              27
# 7                     Adaptive bifurcated matrix              21
# 8                   Expanded full-range protocol              40
# 9                       Monitored local encoding              15
# 10                    Extended didactic approach               7
# 11                    Robust user-facing project               4
# 12                    Configurable didactic core              42
# 13               Down-sized even-keeled attitude              18
# 14      Compatible even-keeled Graphic Interface              19
# 15        Decentralized maximized data-warehouse              50
# 16                 Optional content-based matrix              14
# 17    Vision-oriented regional Graphic Interface              51
# 18                   Synergized coherent synergy              60
# 19                  Reactive background matrices              14
# 20                   Progressive executive array              21
# 21           Synergized 6thgeneration complexity              12
# 22                Managed homogeneous middleware               5
# 23                Reactive transitional database              22
# 24  Switchable upward-trending Graphic Interface              12
# 25            Right-sized user-facing capability              17
# 26        Customer-focused zero-defect challenge               7
# 27     Cross-group fresh-thinking knowledge user              28
# 28         Proactive grid-enabled conglomeration              28
#
#     total_completed  completion_rate
# 0                 5        15.625000
# 1                 0         0.000000
# 2                 0         0.000000
# 3                 0         0.000000
# 4                 0         0.000000
# 5                 0         0.000000
# 6                 0         0.000000
# 7                 3        14.285714
# 8                 0         0.000000
# 9                 0         0.000000
# 10                0         0.000000
# 11                0         0.000000
# 12                0         0.000000
# 13                0         0.000000
# 14                0         0.000000
# 15                0         0.000000
# 16                0         0.000000
# 17                0         0.000000
# 18                5         8.333333
# 19                0         0.000000
# 20                0         0.000000
# 21                0         0.000000
# 22                0         0.000000
# 23                0         0.000000
# 24                0         0.000000
# 25                0         0.000000
# 26                0         0.000000
# 27                0         0.000000
# 28                0         0.000000

# %%
top_5_completion_rate = course_completion_kpi.nlargest(5, 'completion_rate')


top_5_completion_rate.head()
# Out:
#                                course_id                         course_title  \
# 0   00ac38e0-4297-47bd-bfc4-11e55ea46076  Profit-focused reciprocal interface
# 7   418ee30c-866c-40d1-bef2-32565d41a10e           Adaptive bifurcated matrix
# 18  a8faead4-39cd-4b23-88e8-26b235b2371b          Synergized coherent synergy
# 1   06d2a954-eaa4-46e8-b258-2e1c6e06430b  Automated well-modulated moratorium
# 2   1d0a930c-f2ce-4c91-87c6-1f164d31b1e9       Exclusive system-worthy portal
#
#     total_enrolled  total_completed  completion_rate
# 0               32                5        15.625000
# 7               21                3        14.285714
# 18              60                5         8.333333
# 1               46                0         0.000000
# 2                3                0         0.000000

# %% [markdown]
# Employee Performance by Course Tag

# %%
employee_performance_by_tag = final_df.groupby(['course_tag']).agg(
    average_performance_score=('performance_score', 'mean'),
    total_employees=('user_id', 'nunique'),
    total_courses=('course_id', 'nunique')
).reset_index()

display(employee_performance_by_tag)
# Out:
#            course_tag  average_performance_score  total_employees  \
# 0       Cybersecurity                  60.386470               20
# 1    Data Engineering                  70.813758               10
# 2        Data Science                  64.069814               12
# 3              DevOps                  63.741797                3
# 4       Generative AI                  76.071429                6
# 5  Mobile Development                  55.256490               15
# 6    Software Testing                  54.030100                6
# 7        UI/UX Design                  55.273353               17
# 8     Web Development                  69.425955               10
#
#    total_courses
# 0              5
# 1              2
# 2              3
# 3              2
# 4              2
# 5              4
# 6              4
# 7              5
# 8              2

# %% [markdown]
# Module Completion KPI

# %%
module_completion_kpi = final_df.groupby(['course_id', 'course_title', 'module_id', 'module_title']).agg(
    completed_modules=('is_completed', 'sum'),
    total_modules=('module_id', 'count'),
    module_completion_rate=('is_completed', lambda x: (x.sum() / len(x)) * 100),
    total_module_duration=('module_duration', 'sum')
).reset_index()

display(module_completion_kpi)
# Out:
#                                 course_id  \
# 0    00ac38e0-4297-47bd-bfc4-11e55ea46076
# 1    00ac38e0-4297-47bd-bfc4-11e55ea46076
# 2    00ac38e0-4297-47bd-bfc4-11e55ea46076
# 3    00ac38e0-4297-47bd-bfc4-11e55ea46076
# 4    00ac38e0-4297-47bd-bfc4-11e55ea46076
# ..                                    ...
# 613  f58d5820-c86c-47ac-829b-96c2cac3f4cb
# 614  f58d5820-c86c-47ac-829b-96c2cac3f4cb
# 615  f58d5820-c86c-47ac-829b-96c2cac3f4cb
# 616  f58d5820-c86c-47ac-829b-96c2cac3f4cb
# 617  f58d5820-c86c-47ac-829b-96c2cac3f4cb
#
#                               course_title  \
# 0      Profit-focused reciprocal interface
# 1      Profit-focused reciprocal interface
# 2      Profit-focused reciprocal interface
# 3      Profit-focused reciprocal interface
# 4      Profit-focused reciprocal interface
# ..                                     ...
# 613  Proactive grid-enabled conglomeration
# 614  Proactive grid-enabled conglomeration
# 615  Proactive grid-enabled conglomeration
# 616  Proactive grid-enabled conglomeration
# 617  Proactive grid-enabled conglomeration
#
#                                 module_id  \
# 0    0342e7f4-42d0-46ca-b33f-c3a90889011a
# 1    10650c2f-cd69-45e6-993e-6a1a395767ec
# 2    139e5179-ab93-4688-9572-00c8c807b920
# 3    1f8779b0-1541-46d3-a6ff-386b8fda2176
# 4    2fd87c5a-6e7d-45d7-8f85-e0904426069d
# ..                                    ...
# 613  e6f93307-1810-4023-aef9-8c338f5bbd1b
# 614  e72ea282-0d46-4280-84aa-31ef5264265e
# 615  ef1b26f8-b8b3-434b-820e-1fa3346dde0a
# 616  f5410257-13a8-42ac-9dd9-42aa82f6cbd8
# 617  f913c9b3-2e2d-4150-bfca-40e0e487b63e
#
#                                         module_title  completed_modules  \
# 0                          Public-key bifurcated hub                1.0
# 1                          Cross-group global portal                0.0
# 2                        Inverse dedicated structure                0.0
# 3                Customizable demand-driven leverage                1.0
# 4                  Compatible homogeneous middleware                0.0
# ..                                               ...                ...
# 613               Optional full-range superstructure                0.0
# 614                   Multi-layered dynamic database                0.0
# 615  Open-architected zero administration complexity                1.0
# 616               Programmable user-facing interface                0.0
# 617         Open-architected optimizing service-desk                0.0
#
#      total_modules  module_completion_rate  total_module_duration
# 0                1                   100.0                   18.0
# 1                1                     0.0                   24.0
# 2                1                     0.0                   20.0
# 3                1                   100.0                   21.0
# 4                1                     0.0                   19.0
# ..             ...                     ...                    ...
# 613              1                     0.0                   23.0
# 614              1                     0.0                   12.0
# 615              1                   100.0                   15.0
# 616              1                     0.0                   17.0
# 617              1                     0.0                   24.0
#
# [618 rows x 8 columns]

# %% [markdown]
# Get unassigned courses of employees

# %%
employee_course_combinations = pd.merge(users_df[['user_id', 'name', 'designation']],
                                        courses_df[['course_id', 'title', 'tag', 'duration', 'modules']],
                                        how='cross')  # Cartesian product

# Merge employee-course combinations with assigned courses to check what's already assigned
assigned_courses = pd.merge(course_assignment_df[['employee_id', 'course_id']],
                            employee_course_combinations,
                            left_on=['employee_id', 'course_id'],
                            right_on=['user_id', 'course_id'],
                            how='right')

# Filter for rows where the course is not yet assigned (i.e., NaN in assignment)
unassigned_courses = assigned_courses[assigned_courses['employee_id'].isna()]

# Drop irrelevant columns
unassigned_courses = unassigned_courses[['user_id', 'name', 'designation', 'course_id', 'title', 'tag', 'duration', 'modules']]

# Save the result as a CSV file
unassigned_courses.to_csv('data_warehouse/report/unassigned_courses.csv', index=False)
