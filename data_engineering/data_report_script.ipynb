# %%
import pandas as pd
import numpy as np

# %%
users_df = pd.read_csv('data_warehouse/staging/users_staging.csv')
course_progress_df = pd.read_csv('data_warehouse/staging/course_progress_staging.csv')
module_progress_df = pd.read_csv('data_warehouse/staging/module_progress_staging.csv')
courses_df = pd.read_csv('data_warehouse/staging/courses_staging.csv')
course_modules_df = pd.read_csv('data_warehouse/staging/modules_staging.csv')
course_assignment_df = pd.read_csv('data_warehouse/staging/course_assignment_staging.csv')

# %%
display(users_df)
list(users_df.columns)
# Out:
#                                   user_id             name  \
# 0    2a6d8fa1-17f3-4bbe-8662-94ac32e3e36a     Tara Salinas
# 1    77616122-6463-4f54-97bf-e41d45e28e0b       Dale Hicks
# 2    eb13e8d5-4c0e-4160-be53-dd87d0b15033       Maria Lara
# 3    641e72d5-859e-4887-a57d-84201be9c066     Matthew Howe
# 4    d8b75720-cc4c-4a26-aab5-09b7e69559a4   Madeline Ramos
# ..                                    ...              ...
# 195  7cab19dc-8dab-4749-801f-2335f158c761  Alexander Smith
# 196  735eaa70-20ec-402e-ac43-317d0ade8a9e   Darren Collins
# 197  a8e79578-86c9-4a31-8296-1720d55cc49d    Jeffrey Small
# 198  3855a262-1914-476d-8b2d-3a95e575e4de     Andrew Burke
# 199  2149f680-19f7-4eaa-957a-62511eb413f4   Erik Rodriguez
#
#                           email               designation           created_at
# 0     feliciaharmon@example.org          Mobile Developer  2024-01-19 04:37:03
# 1            alan03@example.com  Cybersecurity Specialist  2024-09-01 06:49:07
# 2          brooke92@example.net            Data Scientist  2024-04-23 11:44:18
# 3      meganramirez@example.com             Web Developer  2024-09-02 19:57:28
# 4          ucarlson@example.net             Data Engineer  2024-07-13 20:05:43
# ..                          ...                       ...                  ...
# 195        jonknapp@example.com  Cybersecurity Specialist  2024-05-04 05:22:24
# 196          juan85@example.com            UI/UX Designer  2024-07-08 04:28:45
# 197        sierra50@example.org           DevOps Engineer  2024-01-25 18:18:33
# 198  jensenangelica@example.net             AI Specialist  2024-07-17 21:22:19
# 199         gwilson@example.net  Cybersecurity Specialist  2024-05-24 18:59:00
#
# [200 rows x 5 columns]
# ['user_id', 'name', 'email', 'designation', 'created_at']

# %%
display(course_progress_df)
list(course_progress_df.columns)
# Out:
#                              progress_id  \
# 0   d91d74a7-cd8a-4020-8a65-77bba28bb3f9
# 1   b0d70bd5-85d7-4af1-8f03-e29d2a6a7593
# 2   a050a8fb-8798-4349-bb1e-b785dae34012
# 3   01d24c0e-39de-4125-8b18-ea84fd438fe0
# 4   983a0502-99f5-4e37-bbfc-1465a7500428
# ..                                   ...
# 95  4414f763-4686-485e-87b9-302141ef580f
# 96  cc4b28f6-737b-4ae3-a1f4-6e4e2f785ad3
# 97  5e312d90-fa41-4be3-80e3-bf3434ea814b
# 98  b7a070b1-2a49-4b8b-bf49-84016501d856
# 99  a169620e-0a23-484a-838a-7010ad4a0a50
#
#                              employee_id  \
# 0   6d19c180-92da-4d5f-9e8d-92030b99f39d
# 1   89af6831-8b40-4fbf-86e4-c1c871105249
# 2   17365fa9-099c-4832-b731-b0405dff9e2c
# 3   f884a6af-afcf-4dd1-ae84-8f5f02804ede
# 4   6483031e-7f1d-402e-a13d-56622e6157ee
# ..                                   ...
# 95  956b2015-ab24-4c4c-b309-e171d296f4cb
# 96  7ba92d62-52bd-48c4-8146-da84e760a18a
# 97  f65e8c67-1b9c-4303-8205-a1eb50b28117
# 98  2c914c16-a68f-4c6c-950c-84f4b86c2a7b
# 99  486784cb-20a9-41d5-a147-2619b685f7fc
#
#                                course_id  completion_percentage  score  \
# 0   106b358b-973e-42b1-9154-94214dc7f604                     13     49
# 1   9e83f157-d468-419d-ad33-136689153d82                     78     81
# 2   7b96c6be-198f-40ea-a457-11b71fc95c61                     72     88
# 3   afa0180e-27c9-40c2-90b9-2c36049628da                     78     51
# 4   106b358b-973e-42b1-9154-94214dc7f604                     86     99
# ..                                   ...                    ...    ...
# 95  5233bd5a-1fb4-4022-9ef4-9885ad9b99f4                     23     89
# 96  ba1779fd-d7f4-488b-8416-d5552dccc631                     41     21
# 97  3edbd79b-fa31-4627-a9e7-a788489c521a                     37     61
# 98  695d5577-cbaa-4e8d-ad22-b8f8de421192                     14     23
# 99  f9623129-3998-4702-9949-2c9984428449                     85     70
#
#    completed_at
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
#
# [100 rows x 6 columns]
# ['progress_id',
#  'employee_id',
#  'course_id',
#  'completion_percentage',
#  'score',
#  'completed_at']

# %%
display(module_progress_df)
list(module_progress_df.columns)
# Out:
#                          module_progress_id  \
# 0      0f14c390-2da9-437e-ac37-3d4c23f3178a
# 1      c0d15e25-bd92-402a-8d5b-ac3b505035a6
# 2      014133a2-1bae-421d-a24d-00d1e533cc09
# 3      361d4fd7-75ed-49b4-86ce-38430ab375f1
# 4      4bac0205-4741-4659-9c6d-83b577035618
# ...                                     ...
# 39995  8b3ca1a4-e19d-4d92-b02d-c7898d8c886b
# 39996  14ec243c-1676-48c2-aea9-adc366c032a0
# 39997  7778c9f8-6f24-4cdf-aebd-9ed2a9c6a7a1
# 39998  fe883e92-52c3-4c24-8e4b-911d6af27d51
# 39999  6c4a5b04-d0b3-49a3-9e8a-fbefddb50f5b
#
#                                 employee_id  \
# 0      2a6d8fa1-17f3-4bbe-8662-94ac32e3e36a
# 1      2a6d8fa1-17f3-4bbe-8662-94ac32e3e36a
# 2      2a6d8fa1-17f3-4bbe-8662-94ac32e3e36a
# 3      2a6d8fa1-17f3-4bbe-8662-94ac32e3e36a
# 4      2a6d8fa1-17f3-4bbe-8662-94ac32e3e36a
# ...                                     ...
# 39995  2149f680-19f7-4eaa-957a-62511eb413f4
# 39996  2149f680-19f7-4eaa-957a-62511eb413f4
# 39997  2149f680-19f7-4eaa-957a-62511eb413f4
# 39998  2149f680-19f7-4eaa-957a-62511eb413f4
# 39999  2149f680-19f7-4eaa-957a-62511eb413f4
#
#                                   course_id  \
# 0      ab51c6e7-897f-40b2-8d96-9acc9628a6d7
# 1      3edbd79b-fa31-4627-a9e7-a788489c521a
# 2      5233bd5a-1fb4-4022-9ef4-9885ad9b99f4
# 3      28584099-5402-4c97-9df7-c41196cebdbe
# 4      a83b5073-16b7-4acd-b748-514eb1a25314
# ...                                     ...
# 39995  28584099-5402-4c97-9df7-c41196cebdbe
# 39996  f31ae959-58d2-437c-bf6e-3b76e3d1e479
# 39997  28584099-5402-4c97-9df7-c41196cebdbe
# 39998  a795581f-3613-443f-a730-ce6ac79674ae
# 39999  106b358b-973e-42b1-9154-94214dc7f604
#
#                                   module_id  is_completed         completed_at
# 0      3a071e87-9825-4a6c-ab55-731395d57a33             1  2024-07-07 19:59:24
# 1      ffb1628c-cdad-4297-90e4-95d2b776a679             1  2024-01-12 05:55:59
# 2      90845b52-62f4-4aa5-ac90-5c8eeff9d625             0                  NaN
# 3      5f6dde75-6ed2-43fa-98f3-1f238460c82a             1  2024-03-17 15:56:54
# 4      039fd068-8181-42e5-8b03-342b5e8b98a9             0                  NaN
# ...                                     ...           ...                  ...
# 39995  a42843d7-e4bc-46aa-97b3-6c5e96b5cea4             1  2024-05-29 19:44:01
# 39996  12674695-3717-464c-acc8-a03fdcab8074             1  2024-01-17 15:55:57
# 39997  775cfed8-e985-46e3-88ee-db69b9dd6e63             0                  NaN
# 39998  db61df88-c807-421d-bdd6-46b7e96dad48             0                  NaN
# 39999  97c2dcb7-db8a-4d7e-bfe3-7a0a934f008a             0                  NaN
#
# [40000 rows x 6 columns]
# ['module_progress_id',
#  'employee_id',
#  'course_id',
#  'module_id',
#  'is_completed',
#  'completed_at']

# %%
display(courses_df)
list(courses_df.columns)
# Out:
#                                course_id  \
# 0   5233bd5a-1fb4-4022-9ef4-9885ad9b99f4
# 1   90496e5e-acdd-418b-ad38-ad214e7a347e
# 2   f31ae959-58d2-437c-bf6e-3b76e3d1e479
# 3   a83b5073-16b7-4acd-b748-514eb1a25314
# 4   3a339568-c338-429e-8aef-293a3ea7f5bb
# 5   a8d520b2-584e-40f8-81b0-e8e538ff1f0c
# 6   959f0001-a7c8-49f4-8bf7-173b2cb863b4
# 7   8e577a9b-05fd-42e0-b632-df1326c8f571
# 8   7b96c6be-198f-40ea-a457-11b71fc95c61
# 9   71377f20-bed9-410b-9fa7-142e3179e9fe
# 10  4f3eb0d3-dd92-4afe-9c6c-cd1634770a52
# 11  ed4cf2ae-f6e7-4e7a-9ab0-a45238edf50a
# 12  28584099-5402-4c97-9df7-c41196cebdbe
# 13  afa0180e-27c9-40c2-90b9-2c36049628da
# 14  dd5f09e3-33aa-46a2-aa3b-3644cf18b167
# 15  a795581f-3613-443f-a730-ce6ac79674ae
# 16  3edbd79b-fa31-4627-a9e7-a788489c521a
# 17  695d5577-cbaa-4e8d-ad22-b8f8de421192
# 18  106b358b-973e-42b1-9154-94214dc7f604
# 19  2ff0eb16-b673-41dc-8f43-332b866d7b90
# 20  3c47df7c-1842-40b3-8899-68e3d95f41c8
# 21  f9623129-3998-4702-9949-2c9984428449
# 22  ba1779fd-d7f4-488b-8416-d5552dccc631
# 23  26992488-3e60-4fa9-aa4b-6d5a4354e20b
# 24  c388b418-ba14-4b9e-ae1f-b6ec6159ab06
# 25  ab51c6e7-897f-40b2-8d96-9acc9628a6d7
# 26  e320cc11-248f-4fa2-9896-aaab2b4bc1ab
# 27  9e83f157-d468-419d-ad33-136689153d82
# 28  0e49b452-3443-4ce9-a35d-53c845e4f60f
# 29  6047372f-c9af-4531-8a73-8bdb89bfb063
#
#                                               title  \
# 0                    Networked analyzing initiative
# 1               Customer-focused composite leverage
# 2                    Up-sized dedicated flexibility
# 3                  Public-key grid-enabled strategy
# 4                Enhanced client-driven methodology
# 5                 Function-based heuristic paradigm
# 6                  Sharable even-keeled flexibility
# 7                   Optimized system-worthy concept
# 8                 Exclusive national info-mediaries
# 9               Focused even-keeled instruction set
# 10                  Polarized static conglomeration
# 11            Streamlined 6thgeneration parallelism
# 12  Horizontal zero administration customer loyalty
# 13              Mandatory logistical data-warehouse
# 14                     Focused 5thgeneration policy
# 15    Horizontal mission-critical pricing structure
# 16                  Public-key asynchronous concept
# 17                 Multi-tiered homogeneous archive
# 18           Versatile zero administration analyzer
# 19                 Implemented static collaboration
# 20               Digitized secondary data-warehouse
# 21               Automated 5thgeneration task-force
# 22                       Streamlined mobile adapter
# 23                     Assimilated secondary matrix
# 24                Down-sized demand-driven paradigm
# 25             User-centric coherent info-mediaries
# 26        Re-contextualized composite system engine
# 27             Customer-focused explicit throughput
# 28                  Future-proofed responsive model
# 29           Compatible context-sensitive structure
#
#                                           description  duration  modules  \
# 0   Through certain since window. Bit play edge qu...       108        3
# 1   Do along sure. Turn despite environment commer...       107        3
# 2   Kind focus brother think. Get rich end leave h...       129       10
# 3   Wait our she none mouth building. Lawyer befor...       106       10
# 4   Man leader play candidate property wife upon. ...       166        8
# 5   Hard number body job beyond both play. Knowled...       106        4
# 6   Environment sure yet read. Force particular im...       150        7
# 7   Along stand future fish. Event appear reality ...       159        5
# 8   Follow player wrong fill buy environment. Peac...        84        7
# 9   Rather region poor American her.\nIncluding up...        79        6
# 10  Born south institution build. The middle have ...       117        3
# 11  All movement fire possible. Bed these director...       128        6
# 12  Here present sort. Officer common small board ...       124        7
# 13  Character condition several arm rather. People...       110        1
# 14  White dinner drive near system speech low chan...       100        8
# 15  Plant now area standard difficult although. Cu...       102        2
# 16  Return little this image effect somebody oppor...       142        3
# 17  Base customer face space personal public. See ...       102        4
# 18  Level course serious race southern position no...       168        9
# 19  Prevent result focus create wife. Hour thousan...       170        8
# 20  However own move share artist. Become kitchen ...       161       10
# 21  Among clear government full cut answer several...       175        2
# 22  Care high kind style. Market reach represent. ...       144        6
# 23  Help senior hope class design decide sense. Ho...        75        3
# 24  Push either third citizen three often. Securit...       107        2
# 25  Use here mother reality ground yes. Day radio ...       170        3
# 26  Value size score bag. Result system north musi...       116       10
# 27  Never product this meeting yes hospital dog. A...       174        5
# 28  Step very serve fear four moment resource. Yes...       128        5
# 29  Since story popular bring last country compare...       146        9
#
#              created_at                 tag
# 0   2024-04-01 17:12:02    Software Testing
# 1   2024-09-25 22:48:47     Web Development
# 2   2024-06-09 10:37:56              DevOps
# 3   2024-02-19 20:58:49              DevOps
# 4   2024-08-18 03:56:03              DevOps
# 5   2024-07-07 16:22:52    Software Testing
# 6   2024-10-08 04:31:32     Web Development
# 7   2024-02-26 06:43:18  Mobile Development
# 8   2024-06-27 05:58:07       Cybersecurity
# 9   2024-09-14 12:06:00    Software Testing
# 10  2024-04-10 08:27:10  Mobile Development
# 11  2024-05-09 18:55:37  Mobile Development
# 12  2024-08-09 00:39:22    Data Engineering
# 13  2024-03-16 11:09:55        UI/UX Design
# 14  2024-01-28 08:17:05    Software Testing
# 15  2024-06-25 21:37:41        UI/UX Design
# 16  2024-01-11 12:16:25       Generative AI
# 17  2024-02-09 08:29:17        UI/UX Design
# 18  2024-02-02 06:52:59    Software Testing
# 19  2024-03-03 06:28:53  Mobile Development
# 20  2024-04-23 02:52:51              DevOps
# 21  2024-04-08 15:35:09  Mobile Development
# 22  2024-04-26 01:26:50        Data Science
# 23  2024-08-26 23:39:07  Mobile Development
# 24  2024-05-04 10:41:26       Generative AI
# 25  2024-07-10 00:43:00        Data Science
# 26  2024-07-18 12:58:53              DevOps
# 27  2024-04-01 23:21:10        UI/UX Design
# 28  2024-08-03 13:50:59    Data Engineering
# 29  2024-03-28 02:40:58       Cybersecurity
# ['course_id',
#  'title',
#  'description',
#  'duration',
#  'modules',
#  'created_at',
#  'tag']

# %%
display(course_modules_df)
list(course_modules_df.columns)
# Out:
#                                 module_id  \
# 0    3a071e87-9825-4a6c-ab55-731395d57a33
# 1    ffb1628c-cdad-4297-90e4-95d2b776a679
# 2    90845b52-62f4-4aa5-ac90-5c8eeff9d625
# 3    5f6dde75-6ed2-43fa-98f3-1f238460c82a
# 4    039fd068-8181-42e5-8b03-342b5e8b98a9
# ..                                    ...
# 195  a42843d7-e4bc-46aa-97b3-6c5e96b5cea4
# 196  12674695-3717-464c-acc8-a03fdcab8074
# 197  775cfed8-e985-46e3-88ee-db69b9dd6e63
# 198  db61df88-c807-421d-bdd6-46b7e96dad48
# 199  97c2dcb7-db8a-4d7e-bfe3-7a0a934f008a
#
#                                 course_id  \
# 0    dd5f09e3-33aa-46a2-aa3b-3644cf18b167
# 1    6047372f-c9af-4531-8a73-8bdb89bfb063
# 2    959f0001-a7c8-49f4-8bf7-173b2cb863b4
# 3    a8d520b2-584e-40f8-81b0-e8e538ff1f0c
# 4    f31ae959-58d2-437c-bf6e-3b76e3d1e479
# ..                                    ...
# 195  f9623129-3998-4702-9949-2c9984428449
# 196  3edbd79b-fa31-4627-a9e7-a788489c521a
# 197  3a339568-c338-429e-8aef-293a3ea7f5bb
# 198  8e577a9b-05fd-42e0-b632-df1326c8f571
# 199  28584099-5402-4c97-9df7-c41196cebdbe
#
#                                         module_title  \
# 0                   Face-to-face discrete encryption
# 1     Future-proofed attitude-oriented knowledgebase
# 2                     Streamlined even-keeled portal
# 3                          Operative 24hour analyzer
# 4                 Upgradable non-volatile middleware
# ..                                               ...
# 195                     Monitored multimedia concept
# 196  Reverse-engineered context-sensitive monitoring
# 197      Team-oriented user-facing Graphic Interface
# 198     Multi-lateral object-oriented conglomeration
# 199                  Compatible composite middleware
#
#                                         module_content  module_duration  \
# 0    Government book important while power. Beyond ...               18
# 1    Size this state else next.\nNice respond expla...               15
# 2    Claim theory sign vote society. Compare someth...               19
# 3    Build green require save. Be interest order fo...               26
# 4    Mission approach bag clear campaign including ...               14
# ..                                                 ...              ...
# 195  Hour strong television analysis win. West room...               21
# 196  Dinner start realize oil at. Rise still prove ...               22
# 197  Effect because reach scientist. Develop sectio...               12
# 198  Training artist nothing collection environment...               19
# 199  Again purpose start nation. Particular militar...               21
#
#               created_at
# 0    2024-03-19 13:59:28
# 1    2024-06-02 22:54:31
# 2    2024-04-25 15:50:16
# 3    2024-04-22 09:14:46
# 4    2024-07-11 07:44:46
# ..                   ...
# 195  2024-06-18 17:20:02
# 196  2024-02-01 20:18:16
# 197  2024-02-27 03:51:16
# 198  2024-05-10 07:49:25
# 199  2024-08-02 08:43:30
#
# [200 rows x 6 columns]
# ['module_id',
#  'course_id',
#  'module_title',
#  'module_content',
#  'module_duration',
#  'created_at']

# %%
display(course_assignment_df)
course_assignment_df.columns
# Out:
#                            assignment_id  \
# 0   36574c57-3c0b-4e33-a1b6-65a0b6c13615
# 1   c26e16c5-22df-4fca-b92a-7ef5af7b77f0
# 2   398c9e8d-e37f-43bd-b662-8bc13657dea1
# 3   afad502d-408f-4cc6-8b95-314ebea595da
# 4   6bd03e8f-09a8-4ad2-94b5-b2d9a4858898
# ..                                   ...
# 95  e1996930-1727-4e36-8ec6-96236521f703
# 96  7b050b22-588c-41b0-9c7d-4d15f084a658
# 97  50ce3eee-0fe9-4722-89cc-55588382943d
# 98  2dfc0722-27cd-4a36-b7ef-24519d41fd92
# 99  4bd5f9bc-d782-4786-b033-78ed1ccc969d
#
#                              employee_id  \
# 0   6d19c180-92da-4d5f-9e8d-92030b99f39d
# 1   89af6831-8b40-4fbf-86e4-c1c871105249
# 2   17365fa9-099c-4832-b731-b0405dff9e2c
# 3   f884a6af-afcf-4dd1-ae84-8f5f02804ede
# 4   6483031e-7f1d-402e-a13d-56622e6157ee
# ..                                   ...
# 95  956b2015-ab24-4c4c-b309-e171d296f4cb
# 96  7ba92d62-52bd-48c4-8146-da84e760a18a
# 97  f65e8c67-1b9c-4303-8205-a1eb50b28117
# 98  2c914c16-a68f-4c6c-950c-84f4b86c2a7b
# 99  486784cb-20a9-41d5-a147-2619b685f7fc
#
#                                course_id          assigned_at
# 0   106b358b-973e-42b1-9154-94214dc7f604  2024-04-22 05:02:46
# 1   9e83f157-d468-419d-ad33-136689153d82  2024-07-10 00:51:53
# 2   7b96c6be-198f-40ea-a457-11b71fc95c61  2024-08-18 01:10:49
# 3   afa0180e-27c9-40c2-90b9-2c36049628da  2024-06-16 00:57:25
# 4   106b358b-973e-42b1-9154-94214dc7f604  2024-01-16 04:14:21
# ..                                   ...                  ...
# 95  5233bd5a-1fb4-4022-9ef4-9885ad9b99f4  2024-04-28 19:59:29
# 96  ba1779fd-d7f4-488b-8416-d5552dccc631  2024-06-13 00:47:56
# 97  3edbd79b-fa31-4627-a9e7-a788489c521a  2024-09-22 14:38:31
# 98  695d5577-cbaa-4e8d-ad22-b8f8de421192  2024-06-13 18:18:25
# 99  f9623129-3998-4702-9949-2c9984428449  2024-08-30 05:32:09
#
# [100 rows x 4 columns]
# Index(['assignment_id', 'employee_id', 'course_id', 'assigned_at'], dtype='object')

# %% [markdown]
# Merge dataframes

# %%
# Step 1: Merge users_df with course_progress_df on employee_id
merged_df = pd.merge(users_df, course_progress_df, left_on='user_id', right_on='employee_id', how='left')

# Step 2: Merge merged_df with courses_df to include course details
merged_df = pd.merge(merged_df, courses_df, on='course_id', how='left')

# Step 3: Merge module_progress_df with course_modules_df to get module details for each course
module_df = pd.merge(module_progress_df, course_modules_df, on='module_id', how='left')

# Step 4: Merge the module_df with merged_df to incorporate module completion info
final_df = pd.merge(merged_df, module_df,left_on=['user_id', 'course_id'], right_on=['employee_id', 'course_id_x'], how='left')

# %%
final_df = final_df[[
    'user_id', 'name', 'email', 'designation',   # From users_df
    'course_id', 'title', 'tag', 'completion_percentage', 'duration', 'score', 'completed_at_x',  # From course_progress_df and courses_df
    'module_id', 'module_title', 'is_completed', 'module_duration', 'completed_at_y'  # From module_progress_df and course_modules_df
]]

# Rename columns for clarity
final_df.rename(columns={
    'completed_at_x': 'course_completed_at',
    'completed_at_y': 'module_completed_at',
    'title': 'course_title',
    'tag': 'course_tag',
    'score': 'course_score',
    'duration': 'course_duration',
}, inplace=True)

# %%
final_df.columns
# Out:
# Index(['user_id', 'name', 'email', 'designation', 'course_id', 'course_title',
#        'course_tag', 'completion_percentage', 'course_duration',
#        'course_score', 'course_completed_at', 'module_id', 'module_title',
#        'is_completed', 'module_duration', 'module_completed_at'],
#       dtype='object')

# %%
final_df
# final_df.to_csv('final_df1.csv',index=False)
# Out:
#                                   user_id            name  \
# 0    2a6d8fa1-17f3-4bbe-8662-94ac32e3e36a    Tara Salinas
# 1    77616122-6463-4f54-97bf-e41d45e28e0b      Dale Hicks
# 2    77616122-6463-4f54-97bf-e41d45e28e0b      Dale Hicks
# 3    77616122-6463-4f54-97bf-e41d45e28e0b      Dale Hicks
# 4    77616122-6463-4f54-97bf-e41d45e28e0b      Dale Hicks
# ..                                    ...             ...
# 756  3855a262-1914-476d-8b2d-3a95e575e4de    Andrew Burke
# 757  3855a262-1914-476d-8b2d-3a95e575e4de    Andrew Burke
# 758  3855a262-1914-476d-8b2d-3a95e575e4de    Andrew Burke
# 759  3855a262-1914-476d-8b2d-3a95e575e4de    Andrew Burke
# 760  2149f680-19f7-4eaa-957a-62511eb413f4  Erik Rodriguez
#
#                           email               designation  \
# 0     feliciaharmon@example.org          Mobile Developer
# 1            alan03@example.com  Cybersecurity Specialist
# 2            alan03@example.com  Cybersecurity Specialist
# 3            alan03@example.com  Cybersecurity Specialist
# 4            alan03@example.com  Cybersecurity Specialist
# ..                          ...                       ...
# 756  jensenangelica@example.net             AI Specialist
# 757  jensenangelica@example.net             AI Specialist
# 758  jensenangelica@example.net             AI Specialist
# 759  jensenangelica@example.net             AI Specialist
# 760         gwilson@example.net  Cybersecurity Specialist
#
#                                 course_id                       course_title  \
# 0                                     NaN                                NaN
# 1    c388b418-ba14-4b9e-ae1f-b6ec6159ab06  Down-sized demand-driven paradigm
# 2    c388b418-ba14-4b9e-ae1f-b6ec6159ab06  Down-sized demand-driven paradigm
# 3    c388b418-ba14-4b9e-ae1f-b6ec6159ab06  Down-sized demand-driven paradigm
# 4    c388b418-ba14-4b9e-ae1f-b6ec6159ab06  Down-sized demand-driven paradigm
# ..                                    ...                                ...
# 756  5233bd5a-1fb4-4022-9ef4-9885ad9b99f4     Networked analyzing initiative
# 757  5233bd5a-1fb4-4022-9ef4-9885ad9b99f4     Networked analyzing initiative
# 758  5233bd5a-1fb4-4022-9ef4-9885ad9b99f4     Networked analyzing initiative
# 759  5233bd5a-1fb4-4022-9ef4-9885ad9b99f4     Networked analyzing initiative
# 760                                   NaN                                NaN
#
#            course_tag  completion_percentage  course_duration  course_score  \
# 0                 NaN                    NaN              NaN           NaN
# 1       Generative AI                   42.0            107.0          71.0
# 2       Generative AI                   42.0            107.0          71.0
# 3       Generative AI                   42.0            107.0          71.0
# 4       Generative AI                   42.0            107.0          71.0
# ..                ...                    ...              ...           ...
# 756  Software Testing                   71.0            108.0          96.0
# 757  Software Testing                   71.0            108.0          96.0
# 758  Software Testing                   71.0            108.0          96.0
# 759  Software Testing                   71.0            108.0          96.0
# 760               NaN                    NaN              NaN           NaN
#
#     course_completed_at                             module_id  \
# 0                   NaN                                   NaN
# 1                   NaN  d0eac17b-6fb8-4292-8ca5-787f86eaddc5
# 2                   NaN  80162e58-06ae-430d-bd02-58f4775b7f25
# 3                   NaN  fb1807c1-0bdc-496a-bef0-f76c228e83bf
# 4                   NaN  f0344e01-554f-4505-9428-02807cbf2c09
# ..                  ...                                   ...
# 756                 NaN  d3af8ac2-e31a-48dd-af8b-931c4e6f3768
# 757                 NaN  44dfacfa-cb7c-4e90-8ff8-0de5da961418
# 758                 NaN  c52f5b43-f520-4968-8fd3-de06ea73b75f
# 759                 NaN  93accfa0-b2dc-4cd7-af51-7ff891219070
# 760                 NaN                                   NaN
#
#                                    module_title  is_completed  \
# 0                                           NaN           NaN
# 1    Re-contextualized client-driven moratorium           1.0
# 2                   Total scalable service-desk           1.0
# 3            Public-key bifurcated secured line           1.0
# 4             Organized multimedia secured line           1.0
# ..                                          ...           ...
# 756              Optimized empowering benchmark           1.0
# 757                    Optional global function           0.0
# 758               Phased actuating productivity           0.0
# 759           Enhanced grid-enabled application           1.0
# 760                                         NaN           NaN
#
#      module_duration  module_completed_at
# 0                NaN                  NaN
# 1               20.0  2024-03-12 14:08:10
# 2               14.0  2024-01-07 17:09:33
# 3               25.0  2024-08-01 09:03:32
# 4               17.0  2024-03-10 05:26:15
# ..               ...                  ...
# 756             25.0  2024-02-07 14:05:26
# 757             17.0                  NaN
# 758             19.0                  NaN
# 759             14.0  2024-07-16 21:20:43
# 760              NaN                  NaN
#
# [761 rows x 16 columns]

# %% [markdown]
# Employee Course KPI: This captures each employee’s course progress (average completion percentage and performance score). This will be useful for understanding how far employees have progressed in their courses and how they’re performing.

# %%
# Group by user and course to calculate total modules and completed modules per course
module_kpi = final_df.groupby(['user_id', 'course_id']).agg(
    total_modules=('module_id', 'count'),        # Total number of modules for the course
    modules_completed=('is_completed', 'sum')   # Number of completed modules (is_completed is 1 for completed)
).reset_index()

module_kpi.columns

display(module_kpi)
# Out:
#                                  user_id  \
# 0   0564dc8a-2c53-44ac-b2ec-499755de840f
# 1   0564dc8a-2c53-44ac-b2ec-499755de840f
# 2   0564dc8a-2c53-44ac-b2ec-499755de840f
# 3   07f6381b-edfe-4f3e-b485-0fc0d9fb6e97
# 4   07f6381b-edfe-4f3e-b485-0fc0d9fb6e97
# ..                                   ...
# 92  f9d271d3-b328-4b2f-89bb-bd1b23ab7d32
# 93  f9d271d3-b328-4b2f-89bb-bd1b23ab7d32
# 94  fc046613-47e8-427e-beb5-699680acb5b8
# 95  fd4a96d9-39b7-4d9b-a9b3-4fcb493e0e0b
# 96  fe5b8301-1b13-4683-8fb5-3e8689f0c4d8
#
#                                course_id  total_modules  modules_completed
# 0   4f3eb0d3-dd92-4afe-9c6c-cd1634770a52              7                4.0
# 1   5233bd5a-1fb4-4022-9ef4-9885ad9b99f4              9                3.0
# 2   c388b418-ba14-4b9e-ae1f-b6ec6159ab06              9                4.0
# 3   8e577a9b-05fd-42e0-b632-df1326c8f571              6                2.0
# 4   a83b5073-16b7-4acd-b748-514eb1a25314              7                2.0
# ..                                   ...            ...                ...
# 92  4f3eb0d3-dd92-4afe-9c6c-cd1634770a52              5                1.0
# 93  959f0001-a7c8-49f4-8bf7-173b2cb863b4              8                4.0
# 94  f9623129-3998-4702-9949-2c9984428449              7                5.0
# 95  e320cc11-248f-4fa2-9896-aaab2b4bc1ab             11                6.0
# 96  4f3eb0d3-dd92-4afe-9c6c-cd1634770a52              4                2.0
#
# [97 rows x 4 columns]

# %%
# Merge the module_kpi with the final_df to incorporate total and completed modules
final_df = pd.merge(final_df, module_kpi, on=['user_id', 'course_id'], how='left')

display(final_df.columns)
# Out:
# Index(['user_id', 'name', 'email', 'designation', 'course_id', 'course_title',
#        'course_tag', 'completion_percentage', 'course_duration',
#        'course_score', 'course_completed_at', 'module_id', 'module_title',
#        'is_completed', 'module_duration', 'module_completed_at',
#        'total_modules', 'modules_completed'],
#       dtype='object')

# %%
# Calculate completed percentage for the modules
final_df['completion_percentage'] = (final_df['modules_completed'] / final_df['total_modules']) * 100

# %%
# Employee KPI: Each employee's course progress with total modules, completed modules, and module completion percentage
employee_course_kpi = final_df.groupby(['user_id', 'name', 'designation', 'course_id', 'course_title', 'course_tag']).agg(
    total_modules=('total_modules', 'first'),
    modules_completed=('modules_completed', 'first'),
    completion_percentage=('completion_percentage', 'first'),
    course_score=('course_score', 'first')
).reset_index()

# %%
def calculate_performance_score(progress_df):
    # Group by employee and calculate total score and total max score
    performance_summary = progress_df.groupby('user_id').agg(
        total_score=('course_score', 'sum'),  # Sum of course scores
        total_max_score=('course_score', lambda x: len(x) * 100),  # Assuming max score for each course is 100
        completed_courses=('completion_percentage', lambda x: (x == 100).sum())  # Count of fully completed courses
    ).reset_index()

    # Calculate performance score as a percentage
    performance_summary['performance_score'] = (performance_summary['total_score'] / performance_summary['total_max_score']) * 100
    return performance_summary

# %%
# Update performance score for each employee
performance_summary = calculate_performance_score(final_df)

# %%
final_df = pd.merge(final_df, performance_summary[['user_id', 'performance_score']], on='user_id', how='left')

# %%
final_df.to_csv('data_warehouse/report/final_df.csv', index=False)

# %%
final_df.columns
# Out:
# Index(['user_id', 'name', 'email', 'designation', 'course_id', 'course_title',
#        'course_tag', 'completion_percentage', 'course_duration',
#        'course_score', 'course_completed_at', 'module_id', 'module_title',
#        'is_completed', 'module_duration', 'module_completed_at',
#        'total_modules', 'modules_completed', 'performance_score'],
#       dtype='object')

# %%
filtered_df = final_df[[
    'user_id', 'name', 'designation', 'course_id', 'course_title', 'course_tag',
    'course_duration','modules_completed', 'total_modules', 'completion_percentage', 'course_score', 'performance_score'
]]

# %%
employee_performance_kpi = filtered_df.groupby([
    'user_id', 'name', 'designation', 'course_id', 'course_title', 'course_tag', 
    'course_duration','modules_completed', 'total_modules', 'completion_percentage', 'course_score', 'performance_score'
]).first().reset_index()

display(employee_performance_kpi)
# Out:
#                                  user_id              name  \
# 0   0564dc8a-2c53-44ac-b2ec-499755de840f     Shawna Flores
# 1   0564dc8a-2c53-44ac-b2ec-499755de840f     Shawna Flores
# 2   0564dc8a-2c53-44ac-b2ec-499755de840f     Shawna Flores
# 3   07f6381b-edfe-4f3e-b485-0fc0d9fb6e97     Ryan Humphrey
# 4   07f6381b-edfe-4f3e-b485-0fc0d9fb6e97     Ryan Humphrey
# ..                                   ...               ...
# 95  f9d271d3-b328-4b2f-89bb-bd1b23ab7d32        James Wong
# 96  f9d271d3-b328-4b2f-89bb-bd1b23ab7d32        James Wong
# 97  fc046613-47e8-427e-beb5-699680acb5b8   Elizabeth Brown
# 98  fd4a96d9-39b7-4d9b-a9b3-4fcb493e0e0b  Patricia Montoya
# 99  fe5b8301-1b13-4683-8fb5-3e8689f0c4d8    Kimberly Cowan
#
#                  designation                             course_id  \
# 0             UI/UX Designer  4f3eb0d3-dd92-4afe-9c6c-cd1634770a52
# 1             UI/UX Designer  5233bd5a-1fb4-4022-9ef4-9885ad9b99f4
# 2             UI/UX Designer  c388b418-ba14-4b9e-ae1f-b6ec6159ab06
# 3              AI Specialist  8e577a9b-05fd-42e0-b632-df1326c8f571
# 4              AI Specialist  a83b5073-16b7-4acd-b748-514eb1a25314
# ..                       ...                                   ...
# 95  Cybersecurity Specialist  4f3eb0d3-dd92-4afe-9c6c-cd1634770a52
# 96  Cybersecurity Specialist  959f0001-a7c8-49f4-8bf7-173b2cb863b4
# 97             Data Engineer  f9623129-3998-4702-9949-2c9984428449
# 98            UI/UX Designer  e320cc11-248f-4fa2-9896-aaab2b4bc1ab
# 99             Data Engineer  4f3eb0d3-dd92-4afe-9c6c-cd1634770a52
#
#                                  course_title          course_tag  \
# 0             Polarized static conglomeration  Mobile Development
# 1              Networked analyzing initiative    Software Testing
# 2           Down-sized demand-driven paradigm       Generative AI
# 3             Optimized system-worthy concept  Mobile Development
# 4            Public-key grid-enabled strategy              DevOps
# ..                                        ...                 ...
# 95            Polarized static conglomeration  Mobile Development
# 96           Sharable even-keeled flexibility     Web Development
# 97         Automated 5thgeneration task-force  Mobile Development
# 98  Re-contextualized composite system engine              DevOps
# 99            Polarized static conglomeration  Mobile Development
#
#     course_duration  modules_completed  total_modules  completion_percentage  \
# 0             117.0                4.0            7.0              57.142857
# 1             108.0                3.0            9.0              33.333333
# 2             107.0                4.0            9.0              44.444444
# 3             159.0                2.0            6.0              33.333333
# 4             106.0                2.0            7.0              28.571429
# ..              ...                ...            ...                    ...
# 95            117.0                1.0            5.0              20.000000
# 96            150.0                4.0            8.0              50.000000
# 97            175.0                5.0            7.0              71.428571
# 98            116.0                6.0           11.0              54.545455
# 99            117.0                2.0            4.0              50.000000
#
#     course_score  performance_score
# 0           73.0          51.400000
# 1           60.0          51.400000
# 2           26.0          51.400000
# 3           45.0          70.307692
# 4           92.0          70.307692
# ..           ...                ...
# 95          24.0          47.384615
# 96          62.0          47.384615
# 97          73.0          73.000000
# 98          21.0          21.000000
# 99          55.0          55.000000
#
# [100 rows x 12 columns]

# %% [markdown]
# TOP 5 EMPLOYEES WITH HIGHEST PERFORMANCE SCORE

# %%
top_5_employees = employee_performance_kpi.nlargest(5, 'performance_score')

top_5_employees.head()
# Out:
#                                  user_id             name      designation  \
# 26  3cd83988-77f8-44d1-84fa-6a43ad4ec8f3     Peter Walker    AI Specialist
# 38  6483031e-7f1d-402e-a13d-56622e6157ee       Teresa Lee    AI Specialist
# 82  e33d2272-1399-4832-8289-920c45920b4c  Caroline Deleon   Data Scientist
# 36  58f0f152-7dee-47c8-92bb-56e1aa4da25a    Brenda Carter  DevOps Engineer
# 23  3855a262-1914-476d-8b2d-3a95e575e4de     Andrew Burke    AI Specialist
#
#                                course_id  \
# 26  959f0001-a7c8-49f4-8bf7-173b2cb863b4
# 38  106b358b-973e-42b1-9154-94214dc7f604
# 82  f9623129-3998-4702-9949-2c9984428449
# 36  9e83f157-d468-419d-ad33-136689153d82
# 23  5233bd5a-1fb4-4022-9ef4-9885ad9b99f4
#
#                               course_title          course_tag  \
# 26        Sharable even-keeled flexibility     Web Development
# 38  Versatile zero administration analyzer    Software Testing
# 82      Automated 5thgeneration task-force  Mobile Development
# 36    Customer-focused explicit throughput        UI/UX Design
# 23          Networked analyzing initiative    Software Testing
#
#     course_duration  modules_completed  total_modules  completion_percentage  \
# 26            150.0                2.0           10.0              20.000000
# 38            168.0                4.0            7.0              57.142857
# 82            175.0                6.0            8.0              75.000000
# 36            174.0                4.0            4.0             100.000000
# 23            108.0                3.0            7.0              42.857143
#
#     course_score  performance_score
# 26          99.0               99.0
# 38          99.0               99.0
# 82          98.0               98.0
# 36          97.0               97.0
# 23          96.0               96.0

# %%
employee_performance_kpi.columns
# Out:
# Index(['user_id', 'name', 'designation', 'course_id', 'course_title',
#        'course_tag', 'course_duration', 'modules_completed', 'total_modules',
#        'completion_percentage', 'course_score', 'performance_score'],
#       dtype='object')

# %%
employee_performance_kpi.to_csv('data_warehouse/report/employee_performance_kpi.csv', index=False)

# %% [markdown]
# Course Completion by Tag

# %%
course_completion_by_tag = final_df.groupby(['course_tag']).agg(
    total_courses=('course_id', 'nunique'),
    total_completed_courses=('completion_percentage', lambda x: (x >= 100).sum()),
    average_completion_percentage=('completion_percentage', 'mean')
).reset_index()

display(course_completion_by_tag)
# Out:
#            course_tag  total_courses  total_completed_courses  \
# 0       Cybersecurity              2                        0
# 1    Data Engineering              2                        0
# 2        Data Science              2                        6
# 3              DevOps              5                        4
# 4       Generative AI              2                        0
# 5  Mobile Development              6                        3
# 6    Software Testing              5                        5
# 7        UI/UX Design              4                        8
# 8     Web Development              2                        0
#
#    average_completion_percentage
# 0                      40.000000
# 1                      47.368421
# 2                      69.696970
# 3                      49.411765
# 4                      47.368421
# 5                      55.319149
# 6                      50.515464
# 7                      46.666667
# 8                      44.615385

# %%
top_5_courses = final_df.nlargest(10, 'completion_percentage')


top_5_courses[['course_id', 'course_title', 'completion_percentage']].head()
# Out:
#                                 course_id                        course_title  \
# 49   3a339568-c338-429e-8aef-293a3ea7f5bb  Enhanced client-driven methodology
# 50   3a339568-c338-429e-8aef-293a3ea7f5bb  Enhanced client-driven methodology
# 51   3a339568-c338-429e-8aef-293a3ea7f5bb  Enhanced client-driven methodology
# 52   3a339568-c338-429e-8aef-293a3ea7f5bb  Enhanced client-driven methodology
# 140  a8d520b2-584e-40f8-81b0-e8e538ff1f0c   Function-based heuristic paradigm
#
#      completion_percentage
# 49                   100.0
# 50                   100.0
# 51                   100.0
# 52                   100.0
# 140                  100.0

# %% [markdown]
# Course Enrollment KPI

# %%
course_enrollment_kpi = final_df.groupby(['course_id', 'course_title']).agg(
    enrolled_employees=('user_id', 'nunique')
).reset_index()

display(course_enrollment_kpi)
# Out:
#                                course_id  \
# 0   0e49b452-3443-4ce9-a35d-53c845e4f60f
# 1   106b358b-973e-42b1-9154-94214dc7f604
# 2   26992488-3e60-4fa9-aa4b-6d5a4354e20b
# 3   28584099-5402-4c97-9df7-c41196cebdbe
# 4   2ff0eb16-b673-41dc-8f43-332b866d7b90
# 5   3a339568-c338-429e-8aef-293a3ea7f5bb
# 6   3c47df7c-1842-40b3-8899-68e3d95f41c8
# 7   3edbd79b-fa31-4627-a9e7-a788489c521a
# 8   4f3eb0d3-dd92-4afe-9c6c-cd1634770a52
# 9   5233bd5a-1fb4-4022-9ef4-9885ad9b99f4
# 10  6047372f-c9af-4531-8a73-8bdb89bfb063
# 11  695d5577-cbaa-4e8d-ad22-b8f8de421192
# 12  71377f20-bed9-410b-9fa7-142e3179e9fe
# 13  7b96c6be-198f-40ea-a457-11b71fc95c61
# 14  8e577a9b-05fd-42e0-b632-df1326c8f571
# 15  90496e5e-acdd-418b-ad38-ad214e7a347e
# 16  959f0001-a7c8-49f4-8bf7-173b2cb863b4
# 17  9e83f157-d468-419d-ad33-136689153d82
# 18  a795581f-3613-443f-a730-ce6ac79674ae
# 19  a83b5073-16b7-4acd-b748-514eb1a25314
# 20  a8d520b2-584e-40f8-81b0-e8e538ff1f0c
# 21  ab51c6e7-897f-40b2-8d96-9acc9628a6d7
# 22  afa0180e-27c9-40c2-90b9-2c36049628da
# 23  ba1779fd-d7f4-488b-8416-d5552dccc631
# 24  c388b418-ba14-4b9e-ae1f-b6ec6159ab06
# 25  dd5f09e3-33aa-46a2-aa3b-3644cf18b167
# 26  e320cc11-248f-4fa2-9896-aaab2b4bc1ab
# 27  ed4cf2ae-f6e7-4e7a-9ab0-a45238edf50a
# 28  f31ae959-58d2-437c-bf6e-3b76e3d1e479
# 29  f9623129-3998-4702-9949-2c9984428449
#
#                                        course_title  enrolled_employees
# 0                   Future-proofed responsive model                   1
# 1            Versatile zero administration analyzer                   3
# 2                      Assimilated secondary matrix                   6
# 3   Horizontal zero administration customer loyalty                   1
# 4                  Implemented static collaboration                   2
# 5                Enhanced client-driven methodology                   4
# 6                Digitized secondary data-warehouse                   4
# 7                   Public-key asynchronous concept                   2
# 8                   Polarized static conglomeration                   5
# 9                    Networked analyzing initiative                   5
# 10           Compatible context-sensitive structure                   2
# 11                 Multi-tiered homogeneous archive                   5
# 12              Focused even-keeled instruction set                   2
# 13                Exclusive national info-mediaries                   4
# 14                  Optimized system-worthy concept                   3
# 15              Customer-focused composite leverage                   3
# 16                 Sharable even-keeled flexibility                   6
# 17             Customer-focused explicit throughput                   4
# 18    Horizontal mission-critical pricing structure                   7
# 19                 Public-key grid-enabled strategy                   2
# 20                Function-based heuristic paradigm                   2
# 21             User-centric coherent info-mediaries                   1
# 22              Mandatory logistical data-warehouse                   2
# 23                       Streamlined mobile adapter                   4
# 24                Down-sized demand-driven paradigm                   4
# 25                     Focused 5thgeneration policy                   2
# 26        Re-contextualized composite system engine                   3
# 27            Streamlined 6thgeneration parallelism                   2
# 28                   Up-sized dedicated flexibility                   1
# 29               Automated 5thgeneration task-force                   5

# %%
top_5_courses = course_enrollment_kpi.nlargest(5, 'enrolled_employees')


top_5_courses.head()
# Out:
#                                course_id  \
# 18  a795581f-3613-443f-a730-ce6ac79674ae
# 2   26992488-3e60-4fa9-aa4b-6d5a4354e20b
# 16  959f0001-a7c8-49f4-8bf7-173b2cb863b4
# 8   4f3eb0d3-dd92-4afe-9c6c-cd1634770a52
# 9   5233bd5a-1fb4-4022-9ef4-9885ad9b99f4
#
#                                      course_title  enrolled_employees
# 18  Horizontal mission-critical pricing structure                   7
# 2                    Assimilated secondary matrix                   6
# 16               Sharable even-keeled flexibility                   6
# 8                 Polarized static conglomeration                   5
# 9                  Networked analyzing initiative                   5

# %% [markdown]
# Course Completion KPI

# %%
course_completion_kpi = final_df.groupby(['course_id', 'course_title']).agg(
    total_enrolled=('user_id', 'count'),
    total_completed=('completion_percentage', lambda x: (x >= 100).sum()),
    completion_rate=('completion_percentage', 'mean')
).reset_index()

course_completion_kpi['completion_rate'] = (course_completion_kpi['total_completed'] / course_completion_kpi['total_enrolled']) * 100

display(course_completion_kpi)
# Out:
#                                course_id  \
# 0   0e49b452-3443-4ce9-a35d-53c845e4f60f
# 1   106b358b-973e-42b1-9154-94214dc7f604
# 2   26992488-3e60-4fa9-aa4b-6d5a4354e20b
# 3   28584099-5402-4c97-9df7-c41196cebdbe
# 4   2ff0eb16-b673-41dc-8f43-332b866d7b90
# 5   3a339568-c338-429e-8aef-293a3ea7f5bb
# 6   3c47df7c-1842-40b3-8899-68e3d95f41c8
# 7   3edbd79b-fa31-4627-a9e7-a788489c521a
# 8   4f3eb0d3-dd92-4afe-9c6c-cd1634770a52
# 9   5233bd5a-1fb4-4022-9ef4-9885ad9b99f4
# 10  6047372f-c9af-4531-8a73-8bdb89bfb063
# 11  695d5577-cbaa-4e8d-ad22-b8f8de421192
# 12  71377f20-bed9-410b-9fa7-142e3179e9fe
# 13  7b96c6be-198f-40ea-a457-11b71fc95c61
# 14  8e577a9b-05fd-42e0-b632-df1326c8f571
# 15  90496e5e-acdd-418b-ad38-ad214e7a347e
# 16  959f0001-a7c8-49f4-8bf7-173b2cb863b4
# 17  9e83f157-d468-419d-ad33-136689153d82
# 18  a795581f-3613-443f-a730-ce6ac79674ae
# 19  a83b5073-16b7-4acd-b748-514eb1a25314
# 20  a8d520b2-584e-40f8-81b0-e8e538ff1f0c
# 21  ab51c6e7-897f-40b2-8d96-9acc9628a6d7
# 22  afa0180e-27c9-40c2-90b9-2c36049628da
# 23  ba1779fd-d7f4-488b-8416-d5552dccc631
# 24  c388b418-ba14-4b9e-ae1f-b6ec6159ab06
# 25  dd5f09e3-33aa-46a2-aa3b-3644cf18b167
# 26  e320cc11-248f-4fa2-9896-aaab2b4bc1ab
# 27  ed4cf2ae-f6e7-4e7a-9ab0-a45238edf50a
# 28  f31ae959-58d2-437c-bf6e-3b76e3d1e479
# 29  f9623129-3998-4702-9949-2c9984428449
#
#                                        course_title  total_enrolled  \
# 0                   Future-proofed responsive model               6
# 1            Versatile zero administration analyzer              26
# 2                      Assimilated secondary matrix              34
# 3   Horizontal zero administration customer loyalty              13
# 4                  Implemented static collaboration              18
# 5                Enhanced client-driven methodology              16
# 6                Digitized secondary data-warehouse              33
# 7                   Public-key asynchronous concept              12
# 8                   Polarized static conglomeration              32
# 9                    Networked analyzing initiative              32
# 10           Compatible context-sensitive structure               9
# 11                 Multi-tiered homogeneous archive              35
# 12              Focused even-keeled instruction set              15
# 13                Exclusive national info-mediaries              26
# 14                  Optimized system-worthy concept              17
# 15              Customer-focused composite leverage              21
# 16                 Sharable even-keeled flexibility              44
# 17             Customer-focused explicit throughput              18
# 18    Horizontal mission-critical pricing structure              59
# 19                 Public-key grid-enabled strategy              14
# 20                Function-based heuristic paradigm              13
# 21             User-centric coherent info-mediaries               7
# 22              Mandatory logistical data-warehouse               8
# 23                       Streamlined mobile adapter              26
# 24                Down-sized demand-driven paradigm              26
# 25                     Focused 5thgeneration policy              11
# 26        Re-contextualized composite system engine              18
# 27            Streamlined 6thgeneration parallelism              10
# 28                   Up-sized dedicated flexibility               4
# 29               Automated 5thgeneration task-force              30
#
#     total_completed  completion_rate
# 0                 0         0.000000
# 1                 0         0.000000
# 2                 3         8.823529
# 3                 0         0.000000
# 4                 0         0.000000
# 5                 4        25.000000
# 6                 0         0.000000
# 7                 0         0.000000
# 8                 0         0.000000
# 9                 0         0.000000
# 10                0         0.000000
# 11                0         0.000000
# 12                0         0.000000
# 13                0         0.000000
# 14                0         0.000000
# 15                0         0.000000
# 16                0         0.000000
# 17                4        22.222222
# 18                4         6.779661
# 19                0         0.000000
# 20                5        38.461538
# 21                0         0.000000
# 22                0         0.000000
# 23                6        23.076923
# 24                0         0.000000
# 25                0         0.000000
# 26                0         0.000000
# 27                0         0.000000
# 28                0         0.000000
# 29                0         0.000000

# %%
top_5_completion_rate = course_completion_kpi.nlargest(5, 'completion_rate')


top_5_completion_rate.head()
# Out:
#                                course_id  \
# 20  a8d520b2-584e-40f8-81b0-e8e538ff1f0c
# 5   3a339568-c338-429e-8aef-293a3ea7f5bb
# 23  ba1779fd-d7f4-488b-8416-d5552dccc631
# 17  9e83f157-d468-419d-ad33-136689153d82
# 2   26992488-3e60-4fa9-aa4b-6d5a4354e20b
#
#                             course_title  total_enrolled  total_completed  \
# 20     Function-based heuristic paradigm              13                5
# 5     Enhanced client-driven methodology              16                4
# 23            Streamlined mobile adapter              26                6
# 17  Customer-focused explicit throughput              18                4
# 2           Assimilated secondary matrix              34                3
#
#     completion_rate
# 20        38.461538
# 5         25.000000
# 23        23.076923
# 17        22.222222
# 2          8.823529

# %% [markdown]
# Employee Performance by Course Tag

# %%
employee_performance_by_tag = final_df.groupby(['course_tag']).agg(
    average_performance_score=('performance_score', 'mean'),
    total_employees=('user_id', 'nunique'),
    total_courses=('course_id', 'nunique')
).reset_index()

display(employee_performance_by_tag)
# Out:
#            course_tag  average_performance_score  total_employees  \
# 0       Cybersecurity                  55.542857                6
# 1    Data Engineering                  67.978697                2
# 2        Data Science                  52.445887                5
# 3              DevOps                  54.980050               14
# 4       Generative AI                  60.762907                6
# 5  Mobile Development                  58.851037               22
# 6    Software Testing                  56.772717               14
# 7        UI/UX Design                  65.670218               17
# 8     Web Development                  65.646458                9
#
#    total_courses
# 0              2
# 1              2
# 2              2
# 3              5
# 4              2
# 5              6
# 6              5
# 7              4
# 8              2

# %% [markdown]
# Module Completion KPI

# %%
module_completion_kpi = final_df.groupby(['course_id', 'course_title', 'module_id', 'module_title']).agg(
    completed_modules=('is_completed', 'sum'),
    total_modules=('module_id', 'count'),
    module_completion_rate=('is_completed', lambda x: (x.sum() / len(x)) * 100),
    total_module_duration=('module_duration', 'sum')
).reset_index()

display(module_completion_kpi)
# Out:
#                                 course_id                        course_title  \
# 0    0e49b452-3443-4ce9-a35d-53c845e4f60f     Future-proofed responsive model
# 1    0e49b452-3443-4ce9-a35d-53c845e4f60f     Future-proofed responsive model
# 2    0e49b452-3443-4ce9-a35d-53c845e4f60f     Future-proofed responsive model
# 3    0e49b452-3443-4ce9-a35d-53c845e4f60f     Future-proofed responsive model
# 4    0e49b452-3443-4ce9-a35d-53c845e4f60f     Future-proofed responsive model
# ..                                    ...                                 ...
# 577  f9623129-3998-4702-9949-2c9984428449  Automated 5thgeneration task-force
# 578  f9623129-3998-4702-9949-2c9984428449  Automated 5thgeneration task-force
# 579  f9623129-3998-4702-9949-2c9984428449  Automated 5thgeneration task-force
# 580  f9623129-3998-4702-9949-2c9984428449  Automated 5thgeneration task-force
# 581  f9623129-3998-4702-9949-2c9984428449  Automated 5thgeneration task-force
#
#                                 module_id  \
# 0    7d08cd86-a3aa-4ea4-b28a-1b4d4552b907
# 1    88f23f08-145f-4886-9568-dc25b1ad9b28
# 2    9580fa28-195e-4177-856b-7ac0ea9c9f7d
# 3    c18a7b69-e556-44af-8323-55a870a88e5d
# 4    d344aaab-5922-4c05-a4ca-7dced49268c0
# ..                                    ...
# 577  ba9e46a6-6490-4534-b4ff-477183089df8
# 578  cbcbc769-e19b-404f-9862-562d6e7b634f
# 579  d0ac8e46-e2ed-43c6-b2a9-b033b724e619
# 580  d0eac17b-6fb8-4292-8ca5-787f86eaddc5
# 581  efd814d9-2d8b-4b97-b383-4f08f38ab77b
#
#                                    module_title  completed_modules  \
# 0                        Balanced 24/7 encoding                1.0
# 1                     Synergized stable adapter                0.0
# 2                  Secured 3rdgeneration portal                0.0
# 3            Multi-lateral full-range help-desk                0.0
# 4                 Grass-roots analyzing concept                1.0
# ..                                          ...                ...
# 577   Multi-tiered systemic process improvement                1.0
# 578             Reactive homogeneous initiative                1.0
# 579              Secured tangible system engine                1.0
# 580  Re-contextualized client-driven moratorium                1.0
# 581             Open-source modular parallelism                1.0
#
#      total_modules  module_completion_rate  total_module_duration
# 0                1                   100.0                   28.0
# 1                1                     0.0                   20.0
# 2                1                     0.0                   25.0
# 3                1                     0.0                   15.0
# 4                1                   100.0                   14.0
# ..             ...                     ...                    ...
# 577              1                   100.0                   19.0
# 578              2                    50.0                   60.0
# 579              1                   100.0                   25.0
# 580              1                   100.0                   20.0
# 581              1                   100.0                   29.0
#
# [582 rows x 8 columns]

# %% [markdown]
# Get unassigned courses of employees

# %%
employee_course_combinations = pd.merge(users_df[['user_id', 'name', 'designation']],
                                        courses_df[['course_id', 'title', 'tag', 'duration', 'modules']],
                                        how='cross')  # Cartesian product

# Merge employee-course combinations with assigned courses to check what's already assigned
assigned_courses = pd.merge(course_assignment_df[['employee_id', 'course_id']],
                            employee_course_combinations,
                            left_on=['employee_id', 'course_id'],
                            right_on=['user_id', 'course_id'],
                            how='right')

# Filter for rows where the course is not yet assigned (i.e., NaN in assignment)
unassigned_courses = assigned_courses[assigned_courses['employee_id'].isna()]

# Drop irrelevant columns
unassigned_courses = unassigned_courses[['user_id', 'name', 'designation', 'course_id', 'title', 'tag', 'duration', 'modules']]

# Save the result as a CSV file
unassigned_courses.to_csv('data_warehouse/report/unassigned_courses.csv', index=False)
